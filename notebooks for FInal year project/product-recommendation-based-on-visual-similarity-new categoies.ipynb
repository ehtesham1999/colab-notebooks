# %% [markdown]
# # Product recommendation based on visual similarity
#
#
# The goal of this experiment is to make a very basic recommender system: for a given fashion product, we want to recommend products that look similar.
#
# This kind of recommender system is often used when browsing shopping websites. They usually appear on product pages as a "you may also like" section.
#
# The idea behind this recommender system is simple: if a customer is showing interest towards a product by browsing its page, he may also be interested by products that are similar.
#
#
# ## How to proceed ?
#
# We will used a pre-trained CNN model from Keras to extract the image features.
#
# Then we will compute similarities between the different products using the previously extracted image features.
#
# Other type of information can be used for this purpose such as the product category, size, color, etc. if the data is available, but that is not the case here.

# %% [markdown]
# ## 0. imports and parameters setup

# %%
import pandas as pd

# %%
#dfmeta = pd.read_csv('E:/Airtel Xstream/fyp datasets/csv files/sports/prod_ratings.csv')

# %%
dfmeta = pd.read_csv('E:/Airtel Xstream/fyp datasets/prod_ratings_sports.csv')

# %%
dfmeta.head()
# Out:
#            userID     prod_ID  rating  \
# 0  A1M2T0J45TTE64  B00004S9I0     5.0
# 1   AGGAQLXPVGM5D  B00004U9J9     5.0
# 2   AK7CAW3N1XZV6  B0000534W2     5.0
# 3   AGGAQLXPVGM5D  B00005AXIY     5.0
# 4  A22CW0ZHY3NJH8  B00005BV0D     5.0
#
#                                            prod_name  \
# 0        Lodge Original Finish Pro Grid/Iron Griddle
# 1  SOG Pentagon Elite I Folding Knife PE14-CP - B...
# 2  TheraBand Exercise Ball, Stability Ball with 6...
# 3       Bushnell Yardage Pro Scout Laser Rangefinder
# 4                    Liberty Mountain Aerobie Sprint
#
#                                               imgurl
# 0  ['https://images-na.ssl-images-amazon.com/imag...
# 1  ['https://images-na.ssl-images-amazon.com/imag...
# 2  ['https://images-na.ssl-images-amazon.com/imag...
# 3  ['https://images-na.ssl-images-amazon.com/imag...
# 4  ['https://images-na.ssl-images-amazon.com/imag...

# %%
dfmeta.shape
# Out:
# (1162, 5)

# %%
import requests

# %%
path = 'E:/Airtel Xstream/fyp datasets/csv files/sports/images/'
for i in range(1000):
    try:
        lst = dfmeta['imgurl'][i]
        res = lst.strip('][').split(',') 
        print(res[0][1:-1])

        url = res[0][1:-1]

        response = requests.get(url)
        if response.status_code == 200:
            with open(path+dfmeta['prod_ID'][i]+".jpg",'wb') as f:
                f.write(response.content)
    except:
        print('no url')
# Out:
# https://images-na.ssl-images-amazon.com/images/I/41KTD3MFQ2L._SS40_.jpg
# https://images-na.ssl-images-amazon.com/images/I/4193xjgsxXL._SS40_.jpg
# https://images-na.ssl-images-amazon.com/images/I/51EUOSyBvSL._SX38_SY50_C
# https://images-na.ssl-images-amazon.com/images/I/510BGNEVE9L._SS40_.jpg
# https://images-na.ssl-images-amazon.com/images/I/41flsJkmkdL._SS40_.jpg
#
# no url
# https://images-na.ssl-images-amazon.com/images/I/41-fyO9FdpL._SS40_.jpg
# https://images-na.ssl-images-amazon.com/images/I/414Wv4R4JwL._SS40_.jpg
# https://images-na.ssl-images-amazon.com/images/I/414Wv4R4JwL._SS40_.jpg
# https://images-na.ssl-images-amazon.com/images/I/416OA2EKsXL._SS40_.jpg
#
# no url
#
# no url
#
# no url
#
# no url
#
# no url
# https://images-na.ssl-images-amazon.com/images/I/41RA2PmkiSL._SS36_.jpg
# https://images-na.ssl-images-amazon.com/images/I/41RA2PmkiSL._SS36_.jpg
# https://images-na.ssl-images-amazon.com/images/I/41RA2PmkiSL._SS36_.jpg
# https://images-na.ssl-images-amazon.com/images/I/41vtQtYfPML._SS40_.jpg
# https://images-na.ssl-images-amazon.com/images/I/51JYLHA62fL._SS40_.jpg
# https://images-na.ssl-images-amazon.com/images/I/41AQr%2BmCj-L._SS36_.jpg
# https://images-na.ssl-images-amazon.com/images/I/41FJLBJpkkL._SS40_.jpg
#
# no url
# https://images-na.ssl-images-amazon.com/images/I/51DrspntxvL._SS40_.jpg
#
# no url
#
# no url
#
# no url
#
# no url
# https://images-na.ssl-images-amazon.com/images/I/61HxjhLVQZL._SS40_.jpg
# https://images-na.ssl-images-amazon.com/images/I/61HxjhLVQZL._SS40_.jpg
# https://images-na.ssl-images-amazon.com/images/I/61HxjhLVQZL._SS40_.jpg
# https://images-na.ssl-images-amazon.com/images/I/51zz2GED9eL._SS40_.jpg
# https://images-na.ssl-images-amazon.com/images/I/41f2H7MFdHL._SS40_.jpg
# https://images-na.ssl-images-amazon.com/images/I/41AfcORDCTL._SS36_.jpg
# https://images-na.ssl-images-amazon.com/images/I/31%2B0AVj4j-L._SS40_.jpg
#
# no url
# https://images-na.ssl-images-amazon.com/images/I/41woH9cchdL._SS40_.jpg
#
# no url
#
# no url
#
# no url
#
# no url
#
# no url
# https://images-na.ssl-images-amazon.com/images/I/413JlHxQS2L._SS40_.jpg
# https://images-na.ssl-images-amazon.com/images/I/41eRjW0rB4L._SS40_.jpg
# https://images-na.ssl-images-amazon.com/images/I/31jxWROiS%2BL._SS40_.jpg
#
# no url
# https://images-na.ssl-images-amazon.com/images/I/31OOIOeoewL._SS36_.jpg
#
# no url
#
# no url
# https://images-na.ssl-images-amazon.com/images/I/310pOzdoNAL._SS40_.jpg
# https://images-na.ssl-images-amazon.com/images/I/31lJIgkzlFL._SS40_.jpg
#
# no url
# https://images-na.ssl-images-amazon.com/images/I/41dHL531xlL._SS40_.jpg
# https://images-na.ssl-images-amazon.com/images/I/41dHL531xlL._SS40_.jpg
# https://images-na.ssl-images-amazon.com/images/I/41dHL531xlL._SS40_.jpg
#
# no url
#
# no url
#
# no url
# https://images-na.ssl-images-amazon.com/images/I/51QtEt55TxL._SS40_.jpg
#
# no url
# https://images-na.ssl-images-amazon.com/images/I/31Pu8%2BMtpTL._SS36_.jpg
# https://images-na.ssl-images-amazon.com/images/I/51
SS40_.jpg
# https://images-na.ssl-images-amazon.com/images/I/41nb36wuRhL._SS40_.jpg
# https://images-na.ssl-images-amazon.com/images/I/41nb36wuRhL._SS40_.jpg
#
# no url
# https://images-na.ssl-images-amazon.com/images/I/41eT9ASqsOL._SS40_.jpg
# https://images-na.ssl-images-amazon.com/images/I/41Ur9vO2DsL._SS40_.jpg
# https://images-na.ssl-images-amazon.com/images/I/51Iu0op53IL._SS40_.jpg
# https://images-na.ssl-images-amazon.com/images/I/51Iu0op53IL._SS40_.jpg
# https://images-na.ssl-images-amazon.com/images/I/51Iu0op53IL._SS40_.jpg
# https://images-na.ssl-images-amazon.com/images/I/51Iu0op53IL._SS40_.jpg
# https://images-na.ssl-images-amazon.com/images/I/31VUyqt-qqL._SS40_.jpg
# https://images-na.ssl-images-amazon.com/images/I/31VUyqt-qqL._SS40_.jpg
# https://images-na.ssl-images-amazon.com/images/I/411jLJBv3jL._SS40_.jpg
# https://images-na.ssl-images-amazon.com/images/I/411jLJBv3jL._SS40_.jpg
# https://images-na.ssl-images-amazon.com/images/I/51D9O8PcaJL._SS40_.jpg
#
# no url
# https://images-na.ssl-images-amazon.com/images/I/41nXoNpR0SL._SS40_.jpg
# https://images-na.ssl-images-amazon.com/images/I/31G3c9QS9sL._SS36_.jpg
# https://images-na.ssl-images-amazon.com/images/I/41M5mRN4vXL._SS40_.jpg

# %%
# !pip install keras
# Out:
# Requirement already satisfied: keras in c:\users\ehtesham\anaconda3\lib\site-packages (2.4.3)
# Requirement already satisfied: numpy>=1.9.1 in c:\users\ehtesham\anaconda3\lib\site-packages (from keras) (1.19.2)
# Requirement already satisfied: pyyaml in c:\users\ehtesham\anaconda3\lib\site-packages (from keras) (5.3.1)
# Requirement already satisfied: scipy>=0.14 in c:\users\ehtesham\anaconda3\lib\site-packages (from keras) (1.5.2)
# Requirement already satisfied: h5py in c:\users\ehtesham\anaconda3\lib\site-packages (from keras) (2.10.0)
# Requirement already satisfied: six in c:\users\ehtesham\anaconda3\lib\site-packages (from h5py->keras) (1.15.0)

# %%
# !pip install tensorflow
# Out:
# Requirement already satisfied: tensorflow in c:\users\ehtesham\anaconda3\lib\site-packages (2.4.0)
# Requirement already satisfied: wrapt~=1.12.1 in c:\users\ehtesham\anaconda3\lib\site-packages (from tensorflow) (1.12.1)
# Requirement already satisfied: google-pasta~=0.2 in c:\users\ehtesham\anaconda3\lib\site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: keras-preprocessing~=1.1.2 in c:\users\ehtesham\anaconda3\lib\site-packages (from tensorflow) (1.1.2)
# Requirement already satisfied: tensorboard~=2.4 in c:\users\ehtesham\anaconda3\lib\site-packages (from tensorflow) (2.4.0)
# Requirement already satisfied: h5py~=2.10.0 in c:\users\ehtesham\anaconda3\lib\site-packages (from tensorflow) (2.10.0)
# Requirement already satisfied: grpcio~=1.32.0 in c:\users\ehtesham\anaconda3\lib\site-packages (from tensorflow) (1.32.0)
# Requirement already satisfied: flatbuffers~=1.12.0 in c:\users\ehtesham\anaconda3\lib\site-packages (from tensorflow) (1.12)
# Requirement already satisfied: six~=1.15.0 in c:\users\ehtesham\anaconda3\lib\site-packages (from tensorflow) (1.15.0)
# Requirement already satisfied: numpy~=1.19.2 in c:\users\ehtesham\anaconda3\lib\site-packages (from tensorflow) (1.19.2)
# Requirement already satisfied: wheel~=0.35 in c:\users\ehtesham\anaconda3\lib\site-packages (from tensorflow) (0.35.1)
# Requirement already satisfied: absl-py~=0.10 in c:\users\ehtesham\anaconda3\lib\site-packages (from tensorflow) (0.11.0)
# Requirement already satisfied: termcolor~=1.1.0 in c:\users\ehtesham\anaconda3\lib\site-packages (from tensorflow) (1.1.0)
# Requirement already satisfied: typing-extensions~=3.7.4 in c:\users\ehtesham\anaconda3\lib\site-packages (from tensorflow) (3.7.4.3)
# Requirement already satisfied: gast==0.3.3 in c:\users\ehtesham\anaconda3\lib\site-packages (from tensorflow) (0.3.3)
# Requirement already satisfied: tensorflow-estimator<2.5.0,>=2.4.0rc0 in c:\users\ehtesham\anaconda3\lib\site-packages (from tensorflow) (2.4.0)
# Requirement already satisfied: astunparse~=1.6.3 in c:\users\ehtesham\anaconda3\lib\site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: opt-einsum~=3.3.0 in c:\users\ehtesham\anaconda3\lib\site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: protobuf>=3.9.2 in c:\users\ehtesham\anaconda3\lib\site-packages (from tensorflow) (3.14.0)
# Requirement already satisfied: google-auth<2,>=1.6.3 in c:\users\ehtesham\anaconda3\lib\site-packages (from tensorboard~=2.4->tensorflow) (1.24.0)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\ehtesham\anaconda3\lib\site-packages (from tensorboard~=2.4->tensorflow) (2.24.0)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\ehtesham\anaconda3\lib\site-packages (from tensorboard~=2.4->tensorflow) (3.3.3)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\ehtesham\anaconda3\lib\site-packages (from tensorboard~=2.4->tensorflow) (0.4.2)
# Requirement already satisfied: werkzeug>=0.11.15 in c:\users\ehtesham\anaconda3\lib\site-packages (from tensorboard~=2.4->tensorflow) (1.0.1)
# Requirement already satisfied: setuptools>=41.0.0 in c:\users\ehtesham\anaconda3\lib\site-packages (from tensorboard~=2.4->tensorflow) (50.3.1.post20201107)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\ehtesham\anaconda3\lib\site-packages (from tensorboard~=2.4->tensorflow) (1.7.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\ehtesham\anaconda3\lib\site-packages (from google-auth<2,>=1.6.3->tensorboard~=2.4->tensorflow) (0.2.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in c:\users\ehtesham\anaconda3\lib\site-packages (from google-auth<2,>=1.6.3->tensorboard~=2.4->tensorflow) (4.2.0)
# Requirement already satisfied: rsa<5,>=3.1.4; python_version >= "3.6" in c:\users\ehtesham\anaconda3\lib\site-packages (from google-auth<2,>=1.6.3->tensorboard~=2.4->tensorflow) (4.6)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\ehtesham\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.4->tensorflow) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\ehtesham\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.4->tensorflow) (1.25.11)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ehtesham\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.4->tensorflow) (2020.6.20)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\users\ehtesham\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.4->tensorflow) (3.0.4)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\ehtesham\anaconda3\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.4->tensorflow) (1.3.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\ehtesham\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<2,>=1.6.3->tensorboard~=2.4->tensorflow) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\ehtesham\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.4->tensorflow) (3.1.0)

# %%
# imports
from keras.applications import vgg16
from keras.preprocessing.image import load_img,img_to_array
from keras.models import Model
from keras.applications.imagenet_utils import preprocess_input

from PIL import Image
import os
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity
import pandas as pd

# %%
# parameters setup
imgs_path = "E:/Airtel Xstream/fyp datasets/csv files/sports/images/"
imgs_model_width, imgs_model_height = 224, 224

nb_closest_images = 5 # number of most similar images to retrieve

# %% [markdown]
# ## 1. load the VGG pre-trained model from Keras
#
# Keras module contains several pre-trained models that can be loaded very easily.
#
# For our recommender system based on visual similarity, we need to load a Convolutional Neural Network (CNN) that will be able to interpret the image contents.
#
# In this example we will load the VGG16 model trained on imagenet, a big labeled images database.
#
# If we take the whole model, we will get an output containing probabilities to belong to certain classes, but that is not what we want.
#
# We want to retrieve all the information that the model was able to get in the images.
#
# In order to do so, we have to remove the last layers of the CNN which are only used for classes predictions.

# %%
# load the model
vgg_model = vgg16.VGG16(weights='imagenet')

# remove the last layers in order to get features instead of predictions
feat_extractor = Model(inputs=vgg_model.input, outputs=vgg_model.get_layer("fc2").output)

# print the layers of the CNN
feat_extractor.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 56, 56, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 28, 28, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 28, 28, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 14, 14, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 7, 7, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 25088)             0
# _________________________________________________________________
# fc1 (Dense)                  (None, 4096)              102764544
# _________________________________________________________________
# fc2 (Dense)                  (None, 4096)              16781312
# =================================================================
# Total params: 134,260,544
# Trainable params: 134,260,544
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## 2. get the images paths

# %%
files = [imgs_path + x for x in os.listdir(imgs_path) if "jpg" in x]
print("number of images:",len(files))
# Out:
# number of images: 445

# %% [markdown]
# ## 3. feed one image into the CNN
#
# First we observe what output we get when putting one image into the CNN.
#
# The following steps are:
# - loading the image
# - preparing the image to feed it into the CNN
# - get the CNN output which will correspond to the image features

# %%
# load an image in PIL format
original = load_img(files[50], target_size=(imgs_model_width, imgs_model_height))
plt.imshow(original)
plt.show()
print("image loaded successfully!")
# Out:
# image loaded successfully!

# %%
# convert the PIL image to a numpy array
# in PIL - image is in (width, height, channel)
# in Numpy - image is in (height, width, channel)
numpy_image = img_to_array(original)

# convert the image / images into batch format
# expand_dims will add an extra dimension to the data at a particular axis
# we want the input matrix to the network to be of the form (batchsize, height, width, channels)
# thus we add the extra dimension to the axis 0.
image_batch = np.expand_dims(numpy_image, axis=0)
print('image batch size', image_batch.shape)

# prepare the image for the VGG model
processed_image = preprocess_input(image_batch.copy())
# Out:
# image batch size (1, 224, 224, 3)

# %% [markdown]
# ## 4. feed all the images into the CNN
#
# We were able to do the feature extraction process for one image. Now let's do it for all our images!

# %%
# load all the images and prepare them for feeding into the CNN

importedImages = []

for f in files:
    filename = f
    original = load_img(filename, target_size=(224, 224))
    numpy_image = img_to_array(original)
    image_batch = np.expand_dims(numpy_image, axis=0)
    
    importedImages.append(image_batch)
    
images = np.vstack(importedImages)

processed_imgs = preprocess_input(images.copy())

# %%
# extract the images features

imgs_features = feat_extractor.predict(processed_imgs)

print("features successfully extracted!")
imgs_features.shape
# Out:
# features successfully extracted!
# (445, 4096)

# %%
file_names = []
for i in range(len(files)):
    last = files[i].split('/')[-1]
    name = last.split('.')[0]
    file_names.append(name)

# %%
file_names
# Out:
# ['B00004S9I0',
#  'B00004U9J9',
#  'B00005AXIY',
#  'B00005BV0D',
#  'B000068CJZ',
#  'B0000789T2',
#  'B00007E1M2',
#  'B0000C53IH',
#  'B0000CA2PA',
#  'B0000V0L9Y',
#  'B0000V2DNG',
#  'B0000WR6W8',
#  'B00012M5MS',
#  'B0001P151W',
#  'B0001W0E7G',
#  'B0001WC898',
#  'B00022KJ16',
#  'B00024JMWG',
#  'B000265SMW',
#  'B0002CQR08',
#  'B0002E86WS',
#  'B0002IKE8I',
#  'B000650YAU',
#  'B00065X222',
#  'B00066U2YM',
#  'B0006FLBSO',
#  'B0007IS74G',
#  'B0007PBNF4',
#  'B0007QCOO2',
#  'B0007TAJ0K',
#  'B0007ZF558',
#  'B0007ZO5TU',
#  'B00094CWA8',
#  'B00095M5DQ',
#  'B00099YIX2',
#  'B00099ZUL6',
#  'B0009J566U',
#  'B0009JXRFC',
#  'B0009KF4GG',
#  'B0009PUPSS',
#  'B0009PUPU6',
#  'B0009PUQ8M',
#  'B0009PUQAU',
#  'B0009PUQM8',
#  'B0009PUR2M',
#  'B0009PURX6',
#  'B0009R96YK',
#  'B0009TUEJE',
#  'B0009VC9YA',
#  'B0009VTTQ6',
#  'B000ACAMJC',
#  'B000AL6HSI',
#  'B000AXRY5Q',
#  'B000B6ACGA',
#  'B000B7OUNK',
#  'B000BB8Y92',
#  'B000BBF2RY',
#  'B000BJKWXK',
#  'B000BO3BME',
#  'B000BR3LHQ',
#  'B000BS05XS',
#  'B000BS05Y2',
#  'B000BSZDP8',
#  'B000BSZDSK',
#  'B000BT1G6W',
#  'B000BT1GAI',
#  'B000BTNLVK',
#  'B000BYAKDM',
#  'B000C128PM',
#  'B000C15HS2',
#  'B000C15MY6',
#  'B000C17HKS',
#  'B000C17I9S',
#  'B000C17L2W',
#  'B000DZGLVY',
#  'B000E158CK',
#  'B000E3C3LC',
#  'B000E3FKTE',
#  'B000E3FKTO',
#  'B000E5BD7K',
#  'B000EHYZM8',
#  'B000EI0VT8',
#  'B000EQCVNY',
#  'B000ES178C',
#  'B000EUD472',
#  'B000EWN8IK',
#  'B000EYP1Z6',
#  'B000F0GXTM',
#  'B000F36TM0',
#  'B000F3S892',
#  'B000FDRQ1S',
#  'B000FEUUEW',
#  'B000FH10F2',
#  'B000FIAUWA',
#  'B000FIAVHE',
#  'B000FIE4AE',
#  'B000FN7UY6',
#  'B000G2TOMM',
#  'B000G64I1A',
#  'B000G7WRBC',
#  'B000GCRWCG',
#  'B000GU6PZ8',
#  'B000H6GZI8',
#  'B000H6QNGM',
#  'B000HBO4M2',
#  'B000HU11ZG',
#  'B000HZA918',
#  'B000HZGTUS',
#  'B000I1BQKO',
#  'B000IE3ZKA',
#  'B000IORU06',
#  'B000IQ9PMA',
#  'B000ITVSSQ',
#  'B000IU11MS',
#  'B000J00XPI',
#  'B000J2KEGY',
#  'B000J2Q0SU',
#  'B000JF20LI',
#  'B000JIJ6Z8',
#  'B000JIME2A',
#  'B000JJGXAI',
#  'B000JZ7JM8',
#  'B000KBEH1W',
#  'B000KFV9GO',
#  'B000KK8ZRU',
#  'B000KKFVRC',
#  'B000KOPGFK',
#  'B000KOVCFI',
#  'B000LCA6PG',
#  'B000LDMQ7G',
#  'B000ML7TYW',
#  'B000NGT2VY',
#  'B000NK0DJA',
#  'B000NOPW5Q',
#  'B000NORUJW',
#  'B000NORVHI',
#  'B000NPWVPE',
#  'B000NQQ50U',
#  'B000NVBYD8',
#  'B000OR115W',
#  'B000OTG7FE',
#  'B000OZI256',
#  'B000P1RO7Q',
#  'B000P3WPHI',
#  'B000P3WPKK',
#  'B000P3WQ86',
#  'B000P40UJC',
#  'B000P43134',
#  'B000P431BG',
#  'B000P4YJC6',
#  'B000P9F1EQ',
#  'B000P9IR6K',
#  'B000P9IR8I',
#  'B000PEM63K',
#  'B000PH013E',
#  'B000PL3MGS',
#  'B000PL709I',
#  'B000QSXMME',
#  'B000R58JM4',
#  'B000R6QR36',
#  'B000RNY7XG',
#  'B000RY61PC',
#  'B000RYAKHC',
#  'B000RZTNSI',
#  'B000S6HZCC',
#  'B000TMIHEU',
#  'B000TTILBC',
#  'B000UGVI4G',
#  'B000UMFT22',
#  'B000UVTDLG',
#  'B000VCDXNS',
#  'B000VL4G30',
#  'B000VN21T4',
#  'B000VUFQM6',
#  'B000VY4OJS',
#  'B000VZ1IJG',
#  'B000W7HMAW',
#  'B000WQ74ME',
#  'B000WSUZ50',
#  'B000XUC11I',
#  'B000XZ5FDY',
#  'B000Y9BRCM',
#  'B000YBEID0',
#  'B000YDK968',
#  'B00104UMZS',
#  'B0010XRMLQ',
#  'B00119KQO4',
#  'B0011ZEJKK',
#  'B00124P7SI',
#  'B00125M48I',
#  'B0012J33OS',
#  'B0012Q2S4W',
#  'B0013CLBLQ',
#  'B0013FR09U',
#  'B0013LM2P6',
#  'B0013R8J48',
#  'B0013RD6OQ',
#  'B0013SZC8S',
#  'B00140Y4JS',
#  'B0014BD3DK',
#  'B0014NHJPQ',
#  'B00158507E',
#  'B001586W4E',
#  'B00158AGHS',
#  'B0015DGBX6',
#  'B0015R1N76',
#  'B0015R1NE4',
#  'B0015R1VVY',
#  'B0015R40JE',
#  'B0015RASS6',
#  'B0015U789A',
#  'B0015WLM40',
#  'B00160CG4G',
#  'B00162KS0S',
#  'B00162OKDY',
#  'B00162TEGC',
#  'B00165X4K6',
#  'B00168PI4S',
#  'B0016A283A',
#  'B0016FVSMC',
#  'B00172UJ6A',
#  'B0017L138E',
#  'B0017RAMCQ',
#  'B0018BLKOU',
#  'B0018MIW04',
#  'B0018S0R38',
#  'B0018VCJTA',
#  'B00190VMFM',
#  'B00192JGDU',
#  'B001949TKS',
#  'B00199NUJY',
#  'B0019MT4Y6',
#  'B0019VWSQ8',
#  'B001AIHFUO',
#  'B001ANYRGE',
#  'B001AO2NU0',
#  'B001ASJDWW',
#  'B001AT3SCC',
#  'B001AT3SWW',
#  'B001AYJF2E',
#  'B001AYOP9M',
#  'B001AZNATC',
#  'B001B7ZB4Q',
#  'B001B8ONZI',
#  'B001BL04PS',
#  'B001BQZOCQ',
#  'B001BQZOQ2',
#  'B001BR4RO6',
#  'B001BR4TJY',
#  'B001BR4VME',
#  'B001BR4VQ0',
#  'B001BRE0G6',
#  'B001C10JUM',
#  'B001C1RQO4',
#  'B001C1UGVO',
#  'B001C55NOA',
#  'B001CJ67E6',
#  'B001CJXB5E',
#  'B001CL3IAU',
#  'B001CPGVB4',
#  'B001CX1F4E',
#  'B001CZ9MRY',
#  'B001CZBDF8',
#  'B001D7FYCI',
#  'B001DC5HG6',
#  'B001DDPFYY',
#  'B001DF02WC',
#  'B001DF3KV2',
#  'B001DF68MA',
#  'B001DMJPLO',
#  'B001DO0G8S',
#  'B001DZO5TS',
#  'B001DZR5D6',
#  'B001DZT8BS',
#  'B001DZTKJI',
#  'B001DZVG3G',
#  'B001E7S5BO',
#  'B001EJRE8C',
#  'B001EUL2DO',
#  'B001EXOA3K',
#  'B001F1YI24',
#  'B001F4SKW0',
#  'B001GFFRP6',
#  'B001GPLXAO',
#  'B001GRSI3C',
#  'B001GUP8JG',
#  'B001H9N8C0',
#  'B001H9N8CA',
#  'B001HBHNMO',
#  'B001HN6CX8',
#  'B001HN9QZY',
#  'B001HX3CDG',
#  'B001IDZHF6',
#  'B001IKHUNQ',
#  'B001IV5ZHS',
#  'B001J690VE',
#  'B001K3JUEI',
#  'B001L0VX2W',
#  'B001L8N5H0',
#  'B001LZ4860',
#  'B001M4HT1G',
#  'B001MK3GFS',
#  'B001MLCTBE',
#  'B001MYCV6E',
#  'B001MYEU0E',
#  'B001MYGLJC',
#  'B001N1CBB6',
#  'B001NDIZIM',
#  'B001NGD56G',
#  'B001NXCFT2',
#  'B001OLNWHM',
#  'B001OLU4U0',
#  'B001OPF80W',
#  'B001OR8KVO',
#  'B001QDR29W',
#  'B001QDR2DS',
#  'B001QKXJJC',
#  'B001QVYT72',
#  'B001QWFH7W',
#  'B001QYBFKS',
#  'B001T7QJ9O',
#  'B001TD9J04',
#  'B001TR7QZA',
#  'B001U7GX8K',
#  'B001UERXOQ',
#  'B001UI5IVM',
#  'B001V2E0QG',
#  'B001V4TPQY',
#  'B001VLFEDU',
#  'B001WIUJXW',
#  'B001WIUO1O',
#  'B001WIYQNG',
#  'B001WJ4DGA',
#  'B001WJ4TKK',
#  'B001WJ4UT0',
#  'B001WJ577O',
#  'B001WJ5AJ4',
#  'B001WJ6908',
#  'B001YK4M18',
#  'B001ZFIA6U',
#  'B00200E0HM',
#  'B0023MHZLA',
#  'B0025C832I',
#  'B0026OOS60',
#  'B00275R1X0',
#  'B0027I0D4G',
#  'B0029BE7AW',
#  'B002ATLAJY',
#  'B002B7LKDG',
#  'B002B7LTBY',
#  'B002BDOHNA',
#  'B002BJBIRW',
#  'B002C9IMVQ',
#  'B002CACMR0',
#  'B002CC6BPM',
#  'B002CLK2GC',
#  'B002E6RERU',
#  'B002E6WV78',
#  'B002HOOC56',
#  'B002IVHQ5Q',
#  'B002MKHR6G',
#  'B002MVHSW8',
#  'B002QZ1RS6',
#  'B002RPFN6W',
#  'B002TALNRS',
#  'B002UIZWTE',
#  'B002UK9WK2',
#  'B002Y2SUU4',
#  'B002YP7L4C',
#  'B00300CG5Y',
#  'B0030BS30K',
#  'B0030DH1U6',
#  'B0030OLMWI',
#  'B0030RSBH4',
#  'B0030UM5BE',
#  'B003178LWS',
#  'B0031YQOZC',
#  'B00340H2TU',
#  'B0034K4YZ0',
#  'B00363PTGI',
#  'B00365NKL2',
#  'B0037DD3RO',
#  'B0037N32VG',
#  'B0037N6IXA',
#  'B0038OYOGG',
#  'B0039RFJI4',
#  'B0039TMFSY',
#  'B003AO2J52',
#  'B003BNZ1KC',
#  'B003CJWRE8',
#  'B003D038PI',
#  'B003D6FFGW',
#  'B003ISKM9K',
#  'B003J44Y74',
#  'B003LQVYGO',
#  'B003LVHZ4O',
#  'B003O20UOW',
#  'B003OATJPU',
#  'B003QUT9OE',
#  'B003R7PU6W',
#  'B003SSQRXU',
#  'B003TPR73G',
#  'B003X082A4',
#  'B003YLWBF4',
#  'B003ZTV6SI',
#  'B00404A566',
#  'B0041EKQSC',
#  'B0041FQZMW',
#  'B0042H69WU',
#  'B0042JFAUK',
#  'B004356WLY',
#  'B00435IPFK',
#  'B0043B51EC',
#  'B0044XE6J0',
#  'B0044XGDNM',
#  'B00452C2IC',
#  'B00466UK18',
#  'B0048970A2',
#  'B0048KFEQI',
#  'B0048KGFHU',
#  'B004AWOLV8',
#  'B004D34EQ6',
#  'B004E2C20Q',
#  'B004HRP1CY',
#  'B004INB6QC',
#  'B004J2KDH0',
#  'B004JUF4G2',
#  'B004KJRVSQ',
#  'B004KLY5CE',
#  'B004LL0VMQ',
#  'B004LRDU4G',
#  'B004LUZCQM',
#  'B004MX3MYC',
#  'B004NKSPR8',
#  'B004P4HH8U',
#  'B004Q17CQY',
#  'B004RR0N8Q',
#  'B004SOPJG4',
#  'B004TNWD40',
#  'B004U5PV5A',
#  'B004U8CP88',
#  'B004U9KIUE',
#  'B004UG9W9A',
#  'B004YF931Y',
#  'B004YLU6O6']

# %% [markdown]
# # 5. compute cosine similarities
#
# Now that we have features for every image, we can compute similarity metrics between every image couple.
#
# We will use here the cosine similarity metric.

# %%
# compute cosine similarities between images

cosSimilarities = cosine_similarity(imgs_features)

# store the results into a pandas dataframe

cos_similarities_df = pd.DataFrame(cosSimilarities, columns=file_names, index=file_names)
cos_similarities_df.head()
# Out:
#             B00004S9I0  B00004U9J9  B00005AXIY  B00005BV0D  B000068CJZ  \
# B00004S9I0    1.000000    0.849941    0.500671    0.446190    0.811662
# B00004U9J9    0.849941    1.000000    0.443891    0.431181    0.758880
# B00005AXIY    0.500671    0.443891    1.000000    0.391470    0.537427
# B00005BV0D    0.446190    0.431181    0.391470    1.000000    0.395961
# B000068CJZ    0.811662    0.758880    0.537427    0.395961    1.000000
#
#             B0000789T2  B00007E1M2  B0000C53IH  B0000CA2PA  B0000V0L9Y  ...  \
# B00004S9I0    0.612450    0.767482    0.615301    0.839653    0.550539  ...
# B00004U9J9    0.608825    0.750641    0.714486    0.854610    0.570999  ...
# B00005AXIY    0.559918    0.536398    0.363782    0.474478    0.530892  ...
# B00005BV0D    0.731890    0.364416    0.395198    0.410513    0.389299  ...
# B000068CJZ    0.547133    0.816459    0.630111    0.837266    0.697978  ...
#
#             B004Q17CQY  B004RR0N8Q  B004SOPJG4  B004TNWD40  B004U5PV5A  \
# B00004S9I0    0.356932    0.897912    0.460464    0.614745    0.573903
# B00004U9J9    0.424100    0.801273    0.479125    0.663350    0.619583
# B00005AXIY    0.313702    0.519069    0.566852    0.436080    0.404429
# B00005BV0D    0.339345    0.399362    0.331459    0.340055    0.404233
# B000068CJZ    0.464556    0.911459    0.492317    0.552117    0.656144
#
#             B004U8CP88  B004U9KIUE  B004UG9W9A  B004YF931Y  B004YLU6O6
# B00004S9I0    0.676009    0.434428    0.848710    0.739146    0.796668
# B00004U9J9    0.655859    0.487064    0.789501    0.758073    0.802275
# B00005AXIY    0.527812    0.467010    0.533520    0.490894    0.507411
# B00005BV0D    0.403888    0.364714    0.394645    0.421899    0.420347
# B000068CJZ    0.808053    0.567676    0.923600    0.756372    0.905787
#
# [5 rows x 445 columns]

# %%
cos_similarities_df.index
# Out:
# Index(['B00004S9I0', 'B00004U9J9', 'B00005AXIY', 'B00005BV0D', 'B000068CJZ',
#        'B0000789T2', 'B00007E1M2', 'B0000C53IH', 'B0000CA2PA', 'B0000V0L9Y',
#        ...
#        'B004Q17CQY', 'B004RR0N8Q', 'B004SOPJG4', 'B004TNWD40', 'B004U5PV5A',
#        'B004U8CP88', 'B004U9KIUE', 'B004UG9W9A', 'B004YF931Y', 'B004YLU6O6'],
#       dtype='object', length=445)

# %%
cos_similarities_df.to_csv('img_similarity_sports.csv')

# %%
ddf = pd.read_csv('img_similarity_sports.csv',index_col=0)
#ddf.rename(columns = {'Unnamed: 0':'prod_ID'}, inplace = True) 
ddf.head()
# Out:
#             B00004S9I0  B00004U9J9  B00005AXIY  B00005BV0D  B000068CJZ  \
# B00004S9I0    1.000000    0.849941    0.500671    0.446190    0.811662
# B00004U9J9    0.849941    1.000000    0.443890    0.431181    0.758880
# B00005AXIY    0.500671    0.443890    1.000000    0.391470    0.537427
# B00005BV0D    0.446190    0.431181    0.391470    1.000000    0.395961
# B000068CJZ    0.811662    0.758880    0.537427    0.395961    1.000000
#
#             B0000789T2  B00007E1M2  B0000C53IH  B0000CA2PA  B0000V0L9Y  ...  \
# B00004S9I0    0.612450    0.767482    0.615301    0.839653    0.550539  ...
# B00004U9J9    0.608825    0.750641    0.714486    0.854610    0.570999  ...
# B00005AXIY    0.559918    0.536398    0.363782    0.474478    0.530892  ...
# B00005BV0D    0.731890    0.364416    0.395198    0.410513    0.389299  ...
# B000068CJZ    0.547133    0.816459    0.630111    0.837266    0.697978  ...
#
#             B004Q17CQY  B004RR0N8Q  B004SOPJG4  B004TNWD40  B004U5PV5A  \
# B00004S9I0    0.356932    0.897912    0.460464    0.614745    0.573903
# B00004U9J9    0.424100    0.801273    0.479125    0.663350    0.619583
# B00005AXIY    0.313702    0.519069    0.566852    0.436080    0.404429
# B00005BV0D    0.339345    0.399362    0.331459    0.340055    0.404233
# B000068CJZ    0.464556    0.911459    0.492317    0.552117    0.656144
#
#             B004U8CP88  B004U9KIUE  B004UG9W9A  B004YF931Y  B004YLU6O6
# B00004S9I0    0.676009    0.434428    0.848710    0.739146    0.796668
# B00004U9J9    0.655859    0.487064    0.789501    0.758073    0.802275
# B00005AXIY    0.527812    0.467010    0.533520    0.490894    0.507411
# B00005BV0D    0.403888    0.364714    0.394645    0.421899    0.420347
# B000068CJZ    0.808053    0.567676    0.923600    0.756372    0.905787
#
# [5 rows x 445 columns]

# %% [markdown]
# # 6. retrieve most similar products
#
# The final step is to implement a function that, for any given product, returns the visually most similar products.

# %%
# function to retrieve the most similar products for a given one

def retrieve_most_similar_products(given_img):

    print("-----------------------------------------------------------------------")
    print("original product:")
    print(given_img)

#     original = load_img(given_img, target_size=(imgs_model_width, imgs_model_height))
#     plt.imshow(original)
#     plt.show()

    print("-----------------------------------------------------------------------")
    print("most similar products:")

    closest_imgs = cos_similarities_df[given_img].sort_values(ascending=False)[1:nb_closest_images+1].index
    closest_imgs_scores = cos_similarities_df[given_img].sort_values(ascending=False)[1:nb_closest_images+1]
    
    


    for i in range(0,len(closest_imgs)):
        print(closest_imgs[i])
#         original = load_img(closest_imgs[i], target_size=(imgs_model_width, imgs_model_height))
#         plt.imshow(original)
#         plt.show()
#         lst = get_product_details(closest_imgs[i])
#         print('title: '+lst[0])
#         print('description: '+lst[1])
#         print("similarity score : ",closest_imgs_scores[i])
    return (closest_imgs)

# %%
retrieve_most_similar_products(file_names[3])
# Out:
# -----------------------------------------------------------------------
# original product:
# B00005BV0D
# -----------------------------------------------------------------------
# most similar products:
# B0000789T2
# B000EYP1Z6
# B0002CQR08
# B0009PUQM8
# B001BL04PS
# Index(['B0000789T2', 'B000EYP1Z6', 'B0002CQR08', 'B0009PUQM8', 'B001BL04PS'], dtype='object')

# %%
retrieve_most_similar_products("B000EYP1Z6")
# Out:
# -----------------------------------------------------------------------
# original product:
# B000EYP1Z6
# -----------------------------------------------------------------------
# most similar products:
# B0002CQR08
# B001L8N5H0
# B000C15HS2
# B0000789T2
# B000ITVSSQ
# Index(['B0002CQR08', 'B001L8N5H0', 'B000C15HS2', 'B0000789T2', 'B000ITVSSQ'], dtype='object')

# %% [markdown]
# # Conclusion
# We saw above that this very basic recommender system is able to find similar products accurately: most of the time the retrieved products have the same purpose and even look very similar.
#
# This could be incorporated directly into a website using a web framework such as Flask.
