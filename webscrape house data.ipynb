# %%
# !pip install scrapy
# Out:
# Requirement already satisfied: scrapy in c:\users\ehtesham\anaconda3\lib\site-packages (2.4.1)
# Requirement already satisfied: cryptography>=2.0 in c:\users\ehtesham\anaconda3\lib\site-packages (from scrapy) (2.1.4)
# Requirement already satisfied: pyOpenSSL>=16.2.0 in c:\users\ehtesham\anaconda3\lib\site-packages (from scrapy) (17.5.0)
# Requirement already satisfied: cssselect>=0.9.1 in c:\users\ehtesham\anaconda3\lib\site-packages (from scrapy) (1.1.0)
# Requirement already satisfied: zope.interface>=4.1.3 in c:\users\ehtesham\anaconda3\lib\site-packages (from scrapy) (5.2.0)
# Requirement already satisfied: queuelib>=1.4.2 in c:\users\ehtesham\anaconda3\lib\site-packages (from scrapy) (1.5.0)
# Requirement already satisfied: service-identity>=16.0.0 in c:\users\ehtesham\anaconda3\lib\site-packages (from scrapy) (18.1.0)
# Requirement already satisfied: lxml>=3.5.0 in c:\users\ehtesham\anaconda3\lib\site-packages (from scrapy) (4.1.1)
# Requirement already satisfied: parsel>=1.5.0 in c:\users\ehtesham\anaconda3\lib\site-packages (from scrapy) (1.6.0)
# Requirement already satisfied: w3lib>=1.17.0 in c:\users\ehtesham\anaconda3\lib\site-packages (from scrapy) (1.22.0)
# Requirement already satisfied: itemadapter>=0.1.0 in c:\users\ehtesham\anaconda3\lib\site-packages (from scrapy) (0.2.0)
# Requirement already satisfied: PyDispatcher>=2.0.5 in c:\users\ehtesham\anaconda3\lib\site-packages (from scrapy) (2.0.5)
# Requirement already satisfied: protego>=0.1.15 in c:\users\ehtesham\anaconda3\lib\site-packages (from scrapy) (0.1.16)
# Requirement already satisfied: Twisted>=17.9.0 in c:\users\ehtesham\anaconda3\lib\site-packages (from scrapy) (20.3.0)
# Requirement already satisfied: itemloaders>=1.0.1 in c:\users\ehtesham\anaconda3\lib\site-packages (from scrapy) (1.0.4)
# Requirement already satisfied: idna>=2.1 in c:\users\ehtesham\anaconda3\lib\site-packages (from cryptography>=2.0->scrapy) (2.6)
# Requirement already satisfied: asn1crypto>=0.21.0 in c:\users\ehtesham\anaconda3\lib\site-packages (from cryptography>=2.0->scrapy) (0.24.0)
# Requirement already satisfied: six>=1.4.1 in c:\users\ehtesham\anaconda3\lib\site-packages (from cryptography>=2.0->scrapy) (1.11.0)
# Requirement already satisfied: cffi>=1.7 in c:\users\ehtesham\anaconda3\lib\site-packages (from cryptography>=2.0->scrapy) (1.11.4)
# Requirement already satisfied: pycparser in c:\users\ehtesham\anaconda3\lib\site-packages (from cffi>=1.7->cryptography>=2.0->scrapy) (2.18)
# Requirement already satisfied: jmespath>=0.9.5 in c:\users\ehtesham\anaconda3\lib\site-packages (from itemloaders>=1.0.1->scrapy) (0.10.0)
# Requirement already satisfied: pyasn1 in c:\users\ehtesham\anaconda3\lib\site-packages (from service-identity>=16.0.0->scrapy) (0.4.8)
# Requirement already satisfied: attrs>=16.0.0 in c:\users\ehtesham\anaconda3\lib\site-packages (from service-identity>=16.0.0->scrapy) (20.3.0)
# Requirement already satisfied: pyasn1-modules in c:\users\ehtesham\anaconda3\lib\site-packages (from service-identity>=16.0.0->scrapy) (0.2.8)
# Requirement already satisfied: PyHamcrest!=1.10.0,>=1.9.0 in c:\users\ehtesham\anaconda3\lib\site-packages (from Twisted>=17.9.0->scrapy) (2.0.2)
# Requirement already satisfied: incremental>=16.10.1 in c:\users\ehtesham\anaconda3\lib\site-packages (from Twisted>=17.9.0->scrapy) (17.5.0)
# Requirement already satisfied: constantly>=15.1 in c:\users\ehtesham\anaconda3\lib\site-packages (from Twisted>=17.9.0->scrapy) (15.1.0)
# Requirement already satisfied: hyperlink>=17.1.1 in c:\users\ehtesham\anaconda3\lib\site-packages (from Twisted>=17.9.0->scrapy) (20.0.1)
# Requirement already satisfied: Automat>=0.3.0 in c:\users\ehtesham\anaconda3\lib\site-packages (from Twisted>=17.9.0->scrapy) (20.2.0)
# Requirement already satisfied: setuptools in c:\users\ehtesham\anaconda3\lib\site-packages (from zope.interface>=4.1.3->scrapy) (38.4.0)

# %%
import scrapy
from scrapy.crawler import CrawlerProcess
import json
import csv

# %%
class Olx(scrapy.Spider):
    name = 'olx'
    
    url = 'https://www.olx.in/api/relevance/v2/search?category=1725&facet_limit=100&lang=en&location=4059014&location_facet_limit=20&platform=web-desktop&size=40&user=16fecf81399x6039b937'
    
    headers = {
        'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/87.0.4280.88 Safari/537.36'
    }
    
    def __init__(self):
        with open('olxdata.csv', 'w') as csv_file:
            csv_file.write('title,description,location,features,date,price,built\n')
    
    def start_requests(self):
        for page in range(0, 5):
            yield scrapy.Request(url=self.url + '&page=' + str(page), headers=self.headers, callback=self.parse)
    
    def parse(self, res):
        data = res.text
        data = json.loads(data)
        
        for offer in data['data']:
            items = {
                'title': offer['title'],
                'description': offer['description'].replace('\n', ' '),
                'location': offer['locations_resolved']['COUNTRY_name'] + ', ' +
                            offer['locations_resolved']['ADMIN_LEVEL_1_name'] + ', ' +
                            offer['locations_resolved']['ADMIN_LEVEL_3_name'] + ', ' +
                            offer['locations_resolved']['SUBLOCALITY_LEVEL_1_name'],
                'features': offer['main_info'],
                'date': offer['display_date'],
                'price': offer['price']['value']['display'],
                'built' : offer['parameters'][6]['value_name'],
                
                
            }
            
            print(json.dumps(items, indent=2))
            
            with open('olxdata.csv', 'a') as csv_file:
                writer = csv.DictWriter(csv_file, fieldnames=items.keys())
                writer.writerow(items)

# %%
# run scraper
process = CrawlerProcess()
process.crawl(Olx)
process.start()

# debug
#Olx.parse(Olx, '')
# Out:
# 2020-12-27 18:47:14 [scrapy.utils.log] INFO: Scrapy 2.4.1 started (bot: scrapybot)
# 2020-12-27 18:47:14 [scrapy.utils.log] INFO: Versions: lxml 4.1.1.0, libxml2 2.9.7, cssselect 1.1.0, parsel 1.6.0, w3lib 1.22.0, Twisted 20.3.0, Python 3.6.4 |Anaconda, Inc.| (default, Jan 16 2018, 10:22:32) [MSC v.1900 64 bit (AMD64)], pyOpenSSL 17.5.0 (OpenSSL 1.0.2u  20 Dec 2019), cryptography 2.1.4, Platform Windows-10-10.0.18362-SP0
# 2020-12-27 18:47:14 [scrapy.utils.log] DEBUG: Using reactor: twisted.internet.selectreactor.SelectReactor
# 2020-12-27 18:47:14 [scrapy.crawler] INFO: Overridden settings:
# {}
# 2020-12-27 18:47:14 [scrapy.extensions.telnet] INFO: Telnet Password: 9d29391f73ad5e34
# 2020-12-27 18:47:14 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.logstats.LogStats']
# 2020-12-27 18:47:15 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2020-12-27 18:47:15 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2020-12-27 18:47:15 [scrapy.middleware] INFO: Enabled item pipelines:
# []
# 2020-12-27 18:47:15 [scrapy.core.engine] INFO: Spider opened
# 2020-12-27 18:47:15 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2020-12-27 18:47:15 [scrapy.extensions.telnet] INFO: Telnet console listening on 127.0.0.1:6026
# 2020-12-27 18:47:16 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.olx.in/api/relevance/v2/search?category=1725&facet_limit=100&lang=en&location=4059014&location_facet_limit=20&platform=web-desktop&size=40&user=16fecf81399x6039b937&page=4> (referer: None)
# 2020-12-27 18:47:16 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.olx.in/api/relevance/v2/search?category=1725&facet_limit=100&lang=en&location=4059014&location_facet_limit=20&platform=web-desktop&size=40&user=16fecf81399x6039b937&page=2> (referer: None)
# 2020-12-27 18:47:16 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.olx.in/api/relevance/v2/search?category=1725&facet_limit=100&lang=en&location=4059014&location_facet_limit=20&platform=web-desktop&size=40&user=16fecf81399x6039b937&page=3> (referer: None)
# 2020-12-27 18:47:16 [scrapy.core.scraper] ERROR: Spider error processing <GET https://www.olx.in/api/relevance/v2/search?category=1725&facet_limit=100&lang=en&location=4059014&location_facet_limit=20&platform=web-desktop&size=40&user=16fecf81399x6039b937&page=4> (referer: None)
# Traceback (most recent call last):
#   File "C:\Users\ehtesham\Anaconda3\lib\site-packages\twisted\internet\defer.py", line 654, in _runCallbacks
#     current.result = callback(current.result, *args, **kw)
#   File "<ipython-input-3-50028141dd70>", line 41, in parse
#     writer.writerow(items)
#   File "C:\Users\ehtesham\Anaconda3\lib\csv.py", line 155, in writerow
#     return self.writer.writerow(self._dict_to_list(rowdict))
#   File "C:\Users\ehtesham\Anaconda3\lib\encodings\cp1252.py", line 19, in encode
#     return codecs.charmap_encode(input,self.errors,encoding_table)[0]
# UnicodeEncodeError: 'charmap' codec can't encode character '\u20b9' in position 185: character maps to <undefined>
# 2020-12-27 18:47:16 [scrapy.core.scraper] ERROR: Spider error processing <GET https://www.olx.in/api/relevance/v2/search?category=1725&facet_limit=100&lang=en&location=4059014&location_facet_limit=20&platform=web-desktop&size=40&user=16fecf81399x6039b937&page=2> (referer: None)
# Traceback (most recent call last):
#   File "C:\Users\ehtesham\Anaconda3\lib\site-packages\twisted\internet\defer.py", line 654, in _runCallbacks
#     current.result = callback(current.result, *args, **kw)
#   File "<ipython-input-3-50028141dd70>", line 41, in parse
#     writer.writerow(items)
#   File "C:\Users\ehtesham\Anaconda3\lib\csv.py", line 155, in writerow
#     return self.writer.writerow(self._dict_to_list(rowdict))
#   File "C:\Users\ehtesham\Anaconda3\lib\encodings\cp1252.py", line 19, in encode
#     return codecs.charmap_encode(input,self.errors,encoding_table)[0]
# UnicodeEncodeError: 'charmap' codec can't encode character '\u20b9' in position 199: character maps to <undefined>
# 2020-12-27 18:47:16 [scrapy.core.scraper] ERROR: Spider error processing <GET https://www.olx.in/api/relevance/v2/search?category=1725&facet_limit=100&lang=en&location=4059014&location_facet_limit=20&platform=web-desktop&size=40&user=16fecf81399x6039b937&page=3> (referer: None)
# Traceback (most recent call last):
#   File "C:\Users\ehtesham\Anaconda3\lib\site-packages\twisted\internet\defer.py", line 654, in _runCallbacks
#     current.result = callback(current.result, *args, **kw)
#   File "<ipython-input-3-50028141dd70>", line 41, in parse
#     writer.writerow(items)
#   File "C:\Users\ehtesham\Anaconda3\lib\csv.py", line 155, in writerow
#     return self.writer.writerow(self._dict_to_list(rowdict))
#   File "C:\Users\ehtesham\Anaconda3\lib\encodings\cp1252.py", line 19, in encode
#     return codecs.charmap_encode(input,self.errors,encoding_table)[0]
# UnicodeEncodeError: 'charmap' codec can't encode character '\u20b9' in position 185: character maps to <undefined>
# {
#   "title": "We are provide all types of loan",
#   "description": "Home loan, personal loan,morgage,and all types of loan",
#   "location": "India, Maharashtra, Pune, New Sadashiv Peth",
#   "features": "1 Bds - 1 Ba - 500 ft2",
#   "date": "2020-12-13T10:43:24+0000",
#   "price": "\u20b9 10,000",
#   "built": "500"
# }
# {
#   "title": "Buy 2 BHK Luxurious Homes in Kondhwa at Rs 44.3 Lac.",
#   "description": "Buy 2 BHK Luxurious Homes in Kondhwa at Rs 44.3 Lac.",
#   "location": "India, Maharashtra, Pune, Pune Cantonment",
#   "features": "2 Bds - 2 Ba - 656 ft2",
#   "date": "2020-12-24T12:21:44+0000",
#   "price": "\u20b9 44,30,000",
#   "built": "656"
# }
# {
#   "title": "Shah Real Estate",
#   "description": "Available 2 bhk flat for sale in khadki bazar in Akashdeep. Near Rani Laxmi Udyan.",
#   "location": "India, Maharashtra, Pune, Kirkee",
#   "features": "2 Bds - 2 Ba - 1050 ft2",
#   "date": "2020-12-21T01:51:27+0000",
#   "price": "\u20b9 55,00,000",
#   "built": "1050"
# }
# 2020-12-27 18:47:16 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.olx.in/api/relevance/v2/search?category=1725&facet_limit=100&lang=en&location=4059014&location_facet_limit=20&platform=web-desktop&size=40&user=16fecf81399x6039b937&page=0> (referer: None)
# 2020-12-27 18:47:16 [scrapy.core.scraper] ERROR: Spider error processing <GET https://www.olx.in/api/relevance/v2/search?category=1725&facet_limit=100&lang=en&location=4059014&location_facet_limit=20&platform=web-desktop&size=40&user=16fecf81399x6039b937&page=0> (referer: None)
# Traceback (most recent call last):
#   File "C:\Users\ehtesham\Anaconda3\lib\site-packages\twisted\internet\defer.py", line 654, in _runCallbacks
#     current.result = callback(current.result, *args, **kw)
#   File "<ipython-input-3-50028141dd70>", line 41, in parse
#     writer.writerow(items)
#   File "C:\Users\ehtesham\Anaconda3\lib\csv.py", line 155, in writerow
#     return self.writer.writerow(self._dict_to_list(rowdict))
#   File "C:\Users\ehtesham\Anaconda3\lib\encodings\cp1252.py", line 19, in encode
#     return codecs.charmap_encode(input,self.errors,encoding_table)[0]
# UnicodeEncodeError: 'charmap' codec can't encode character '\u20b9' in position 515: character maps to <undefined>
# 2020-12-27 18:47:16 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.olx.in/api/relevance/v2/search?category=1725&facet_limit=100&lang=en&location=4059014&location_facet_limit=20&platform=web-desktop&size=40&user=16fecf81399x6039b937&page=1> (referer: None)
# 2020-12-27 18:47:16 [scrapy.core.scraper] ERROR: Spider error processing <GET https://www.olx.in/api/relevance/v2/search?category=1725&facet_limit=100&lang=en&location=4059014&location_facet_limit=20&platform=web-desktop&size=40&user=16fecf81399x6039b937&page=1> (referer: None)
# Traceback (most recent call last):
#   File "C:\Users\ehtesham\Anaconda3\lib\site-packages\twisted\internet\defer.py", line 654, in _runCallbacks
#     current.result = callback(current.result, *args, **kw)
#   File "<ipython-input-3-50028141dd70>", line 41, in parse
#     writer.writerow(items)
#   File "C:\Users\ehtesham\Anaconda3\lib\csv.py", line 155, in writerow
#     return self.writer.writerow(self._dict_to_list(rowdict))
#   File "C:\Users\ehtesham\Anaconda3\lib\encodings\cp1252.py", line 19, in encode
#     return codecs.charmap_encode(input,self.errors,encoding_table)[0]
# UnicodeEncodeError: 'charmap' codec can't encode character '\u20b9' in position 352: character maps to <undefined>
# {
#   "title": "2 BHK Luxury Appartment at prime location near Vishrantwadi, Kalas",
#   "description": "2 BHK fully Furnished flat for sale Location : Kalas, Vishrantwadi. With or without furniture option available. All amenities including swimming pool and gym. Kids play area. Ample walking space around society premises. A luxury stay experience. Swimming pool view. 24 by 7 water supply Airy rooms with terrace Modular kitchen trolley Full ventilation",
#   "location": "India, Maharashtra, Pune, Vishrant Wadi",
#   "features": "2 Bds - 2 Ba - 1450 ft2",
#   "date": "2020-11-30T06:35:49+0000",
#   "price": "\u20b9 75,00,000",
#   "built": "1450"
# }
# {
#   "title": "Best ROI on your project in , Bavdhan East",
#   "description": "%%Goel Ganga Legends County at Bavdhan is much, much more than a residential project. It is an ecosystem designed for today\u2019s young and ambitious human capital that desires the perfect work-life-fitness balance.%%",
#   "location": "India, Maharashtra, Pune, Shivaji Nagar",
#   "features": "2 Bds - 2 Ba - 783 ft2",
#   "date": "2020-12-26T08:11:45+0000",
#   "price": "\u20b9 82,00,234",
#   "built": "783"
# }
# 2020-12-27 18:47:16 [scrapy.core.engine] INFO: Closing spider (finished)
# 2020-12-27 18:47:16 [scrapy.statscollectors] INFO: Dumping Scrapy stats:
# {'downloader/request_bytes': 2270,
#  'downloader/request_count': 5,
#  'downloader/request_method_count/GET': 5,
#  'downloader/response_bytes': 188488,
#  'downloader/response_count': 5,
#  'downloader/response_status_count/200': 5,
#  'elapsed_time_seconds': 1.572016,
#  'finish_reason': 'finished',
#  'finish_time': datetime.datetime(2020, 12, 27, 13, 17, 16, 954945),
#  'log_count/DEBUG': 5,
#  'log_count/ERROR': 5,
#  'log_count/INFO': 10,
#  'response_received_count': 5,
#  'scheduler/dequeued': 5,
#  'scheduler/dequeued/memory': 5,
#  'scheduler/enqueued': 5,
#  'scheduler/enqueued/memory': 5,
#  'spider_exceptions/UnicodeEncodeError': 5,
#  'start_time': datetime.datetime(2020, 12, 27, 13, 17, 15, 382929)}
# 2020-12-27 18:47:16 [scrapy.core.engine] INFO: Spider closed (finished)
