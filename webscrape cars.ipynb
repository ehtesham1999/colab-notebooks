# %%
# !pip install scrapy
# Out:
# Requirement already satisfied: scrapy in c:\users\ehtesham\anaconda3\lib\site-packages (2.4.1)
# Requirement already satisfied: w3lib>=1.17.0 in c:\users\ehtesham\anaconda3\lib\site-packages (from scrapy) (1.22.0)
# Requirement already satisfied: Twisted>=17.9.0 in c:\users\ehtesham\anaconda3\lib\site-packages (from scrapy) (20.3.0)
# Requirement already satisfied: queuelib>=1.4.2 in c:\users\ehtesham\anaconda3\lib\site-packages (from scrapy) (1.5.0)
# Requirement already satisfied: itemadapter>=0.1.0 in c:\users\ehtesham\anaconda3\lib\site-packages (from scrapy) (0.2.0)
# Requirement already satisfied: lxml>=3.5.0 in c:\users\ehtesham\anaconda3\lib\site-packages (from scrapy) (4.1.1)
# Requirement already satisfied: itemloaders>=1.0.1 in c:\users\ehtesham\anaconda3\lib\site-packages (from scrapy) (1.0.4)
# Requirement already satisfied: cryptography>=2.0 in c:\users\ehtesham\anaconda3\lib\site-packages (from scrapy) (2.1.4)
# Requirement already satisfied: protego>=0.1.15 in c:\users\ehtesham\anaconda3\lib\site-packages (from scrapy) (0.1.16)
# Requirement already satisfied: PyDispatcher>=2.0.5 in c:\users\ehtesham\anaconda3\lib\site-packages (from scrapy) (2.0.5)
# Requirement already satisfied: zope.interface>=4.1.3 in c:\users\ehtesham\anaconda3\lib\site-packages (from scrapy) (5.2.0)
# Requirement already satisfied: cssselect>=0.9.1 in c:\users\ehtesham\anaconda3\lib\site-packages (from scrapy) (1.1.0)
# Requirement already satisfied: parsel>=1.5.0 in c:\users\ehtesham\anaconda3\lib\site-packages (from scrapy) (1.6.0)
# Requirement already satisfied: service-identity>=16.0.0 in c:\users\ehtesham\anaconda3\lib\site-packages (from scrapy) (18.1.0)
# Requirement already satisfied: pyOpenSSL>=16.2.0 in c:\users\ehtesham\anaconda3\lib\site-packages (from scrapy) (17.5.0)
# Requirement already satisfied: idna>=2.1 in c:\users\ehtesham\anaconda3\lib\site-packages (from cryptography>=2.0->scrapy) (2.6)
# Requirement already satisfied: asn1crypto>=0.21.0 in c:\users\ehtesham\anaconda3\lib\site-packages (from cryptography>=2.0->scrapy) (0.24.0)
# Requirement already satisfied: six>=1.4.1 in c:\users\ehtesham\anaconda3\lib\site-packages (from cryptography>=2.0->scrapy) (1.11.0)
# Requirement already satisfied: cffi>=1.7 in c:\users\ehtesham\anaconda3\lib\site-packages (from cryptography>=2.0->scrapy) (1.11.4)
# Requirement already satisfied: pycparser in c:\users\ehtesham\anaconda3\lib\site-packages (from cffi>=1.7->cryptography>=2.0->scrapy) (2.18)
# Requirement already satisfied: jmespath>=0.9.5 in c:\users\ehtesham\anaconda3\lib\site-packages (from itemloaders>=1.0.1->scrapy) (0.10.0)
# Requirement already satisfied: pyasn1-modules in c:\users\ehtesham\anaconda3\lib\site-packages (from service-identity>=16.0.0->scrapy) (0.2.8)
# Requirement already satisfied: attrs>=16.0.0 in c:\users\ehtesham\anaconda3\lib\site-packages (from service-identity>=16.0.0->scrapy) (20.3.0)
# Requirement already satisfied: pyasn1 in c:\users\ehtesham\anaconda3\lib\site-packages (from service-identity>=16.0.0->scrapy) (0.4.8)
# Requirement already satisfied: hyperlink>=17.1.1 in c:\users\ehtesham\anaconda3\lib\site-packages (from Twisted>=17.9.0->scrapy) (20.0.1)
# Requirement already satisfied: Automat>=0.3.0 in c:\users\ehtesham\anaconda3\lib\site-packages (from Twisted>=17.9.0->scrapy) (20.2.0)
# Requirement already satisfied: constantly>=15.1 in c:\users\ehtesham\anaconda3\lib\site-packages (from Twisted>=17.9.0->scrapy) (15.1.0)
# Requirement already satisfied: incremental>=16.10.1 in c:\users\ehtesham\anaconda3\lib\site-packages (from Twisted>=17.9.0->scrapy) (17.5.0)
# Requirement already satisfied: PyHamcrest!=1.10.0,>=1.9.0 in c:\users\ehtesham\anaconda3\lib\site-packages (from Twisted>=17.9.0->scrapy) (2.0.2)
# Requirement already satisfied: setuptools in c:\users\ehtesham\anaconda3\lib\site-packages (from zope.interface>=4.1.3->scrapy) (38.4.0)

# %%
import scrapy
from scrapy.crawler import CrawlerProcess
import json
import csv

# %%
class Olx(scrapy.Spider):
    name = 'olx'
    
    url = 'https://www.olx.in/api/relevance/v2/search?category=84&facet_limit=100&lang=en&location=4059014&location_facet_limit=20&platform=web-desktop&size=40&user=16fecf81399x6039b937'
    
    headers = {
        'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/87.0.4280.88 Safari/537.36'
    }
    
    def __init__(self):
        with open('olxcarsdata.csv', 'w') as csv_file:
            csv_file.write('title,location,price,body_type,brand,model,variant,year,fuel,transmission,kms,owners\n')
    
    def start_requests(self):
        for page in range(0, 10):
            yield scrapy.Request(url=self.url + '&page=' + str(page), headers=self.headers, callback=self.parse)
    
    def parse(self, res):
        data = res.text
        data = json.loads(data)
        
        for offer in data['data']:
            items = {
                'title': offer['title'],
                'location': offer['locations_resolved']['COUNTRY_name'] + ', ' +
                            offer['locations_resolved']['ADMIN_LEVEL_1_name'] + ', ' +
                            offer['locations_resolved']['ADMIN_LEVEL_3_name'] + ', ' +
                            offer['locations_resolved']['SUBLOCALITY_LEVEL_1_name'],
                'price': offer['price']['value']['display'][2:],
                'body_type': offer['car_body_type'],
                'brand' : offer['parameters'][0]['value_name'],
                'model' : offer['parameters'][1]['value_name'],
                'variant' : offer['parameters'][2]['value_name'],
                'year' : offer['parameters'][3]['value_name'],
                'fuel' : offer['parameters'][4]['value_name'],
                'transmission' : offer['parameters'][5]['value_name'],
                'kms' : offer['parameters'][6]['value_name'],
                'owners' : offer['parameters'][7]['value_name'][:1]
                
            }
            
            print(json.dumps(items, indent=2))
            
            with open('olxcarsdata.csv', 'a') as csv_file:
                writer = csv.DictWriter(csv_file, fieldnames=items.keys())
                writer.writerow(items)

# %%
# run scraper
process = CrawlerProcess()
process.crawl(Olx)
process.start()

# debug
#Olx.parse(Olx, '')
# Out:
# 2020-12-27 19:40:16 [scrapy.utils.log] INFO: Scrapy 2.4.1 started (bot: scrapybot)
# 2020-12-27 19:40:16 [scrapy.utils.log] INFO: Versions: lxml 4.1.1.0, libxml2 2.9.7, cssselect 1.1.0, parsel 1.6.0, w3lib 1.22.0, Twisted 20.3.0, Python 3.6.4 |Anaconda, Inc.| (default, Jan 16 2018, 10:22:32) [MSC v.1900 64 bit (AMD64)], pyOpenSSL 17.5.0 (OpenSSL 1.0.2u  20 Dec 2019), cryptography 2.1.4, Platform Windows-10-10.0.18362-SP0
# 2020-12-27 19:40:16 [scrapy.utils.log] DEBUG: Using reactor: twisted.internet.selectreactor.SelectReactor
# 2020-12-27 19:40:16 [scrapy.crawler] INFO: Overridden settings:
# {}
# 2020-12-27 19:40:16 [scrapy.extensions.telnet] INFO: Telnet Password: 5a4b130a4092bac2
# 2020-12-27 19:40:17 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.logstats.LogStats']
# 2020-12-27 19:40:17 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2020-12-27 19:40:17 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2020-12-27 19:40:17 [scrapy.middleware] INFO: Enabled item pipelines:
# []
# 2020-12-27 19:40:17 [scrapy.core.engine] INFO: Spider opened
# 2020-12-27 19:40:17 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2020-12-27 19:40:17 [scrapy.extensions.telnet] INFO: Telnet console listening on 127.0.0.1:6023
# 2020-12-27 19:40:17 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.olx.in/api/relevance/v2/search?category=84&facet_limit=100&lang=en&location=4059014&location_facet_limit=20&platform=web-desktop&size=40&user=16fecf81399x6039b937&page=3> (referer: None)
# 2020-12-27 19:40:17 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.olx.in/api/relevance/v2/search?category=84&facet_limit=100&lang=en&location=4059014&location_facet_limit=20&platform=web-desktop&size=40&user=16fecf81399x6039b937&page=0> (referer: None)
# 2020-12-27 19:40:17 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.olx.in/api/relevance/v2/search?category=84&facet_limit=100&lang=en&location=4059014&location_facet_limit=20&platform=web-desktop&size=40&user=16fecf81399x6039b937&page=4> (referer: None)
# 2020-12-27 19:40:17 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.olx.in/api/relevance/v2/search?category=84&facet_limit=100&lang=en&location=4059014&location_facet_limit=20&platform=web-desktop&size=40&user=16fecf81399x6039b937&page=2> (referer: None)
# 2020-12-27 19:40:17 [scrapy.core.scraper] ERROR: Spider error processing <GET https://www.olx.in/api/relevance/v2/search?category=84&facet_limit=100&lang=en&location=4059014&location_facet_limit=20&platform=web-desktop&size=40&user=16fecf81399x6039b937&page=3> (referer: None)
# Traceback (most recent call last):
#   File "C:\Users\ehtesham\Anaconda3\lib\site-packages\twisted\internet\defer.py", line 654, in _runCallbacks
#     current.result = callback(current.result, *args, **kw)
#   File "<ipython-input-3-f7d0bf8fb4b9>", line 38, in parse
#     'owners' : offer['parameters'][7]['value_name'][:1]
# IndexError: list index out of range
# 2020-12-27 19:40:17 [scrapy.core.scraper] ERROR: Spider error processing <GET https://www.olx.in/api/relevance/v2/search?category=84&facet_limit=100&lang=en&location=4059014&location_facet_limit=20&platform=web-desktop&size=40&user=16fecf81399x6039b937&page=0> (referer: None)
# Traceback (most recent call last):
#   File "C:\Users\ehtesham\Anaconda3\lib\site-packages\twisted\internet\defer.py", line 654, in _runCallbacks
#     current.result = callback(current.result, *args, **kw)
#   File "<ipython-input-3-f7d0bf8fb4b9>", line 46, in parse
#     writer.writerow(items)
#   File "C:\Users\ehtesham\Anaconda3\lib\csv.py", line 155, in writerow
#     return self.writer.writerow(self._dict_to_list(rowdict))
#   File "C:\Users\ehtesham\Anaconda3\lib\encodings\cp1252.py", line 19, in encode
#     return codecs.charmap_encode(input,self.errors,encoding_table)[0]
# UnicodeEncodeError: 'charmap' codec can't encode characters in position 0-2: character maps to <undefined>
# 2020-12-27 19:40:17 [scrapy.core.scraper] ERROR: Spider error processing <GET https://www.olx.in/api/relevance/v2/search?category=84&facet_limit=100&lang=en&location=4059014&location_facet_limit=20&platform=web-desktop&size=40&user=16fecf81399x6039b937&page=4> (referer: None)
# Traceback (most recent call last):
#   File "C:\Users\ehtesham\Anaconda3\lib\site-packages\twisted\internet\defer.py", line 654, in _runCallbacks
#     current.result = callback(current.result, *args, **kw)
#   File "<ipython-input-3-f7d0bf8fb4b9>", line 30, in parse
#     'body_type': offer['car_body_type'],
# KeyError: 'car_body_type'
# 2020-12-27 19:40:17 [scrapy.core.scraper] ERROR: Spider error processing <GET https://www.olx.in/api/relevance/v2/search?category=84&facet_limit=100&lang=en&location=4059014&location_facet_limit=20&platform=web-desktop&size=40&user=16fecf81399x6039b937&page=2> (referer: None)
# Traceback (most recent call last):
#   File "C:\Users\ehtesham\Anaconda3\lib\site-packages\twisted\internet\defer.py", line 654, in _runCallbacks
#     current.result = callback(current.result, *args, **kw)
#   File "<ipython-input-3-f7d0bf8fb4b9>", line 36, in parse
#     'transmission' : offer['parameters'][5]['value_name'],
# IndexError: list index out of range
# {
#   "title": "Audi Q7 3.0 TDI quattro Premium, 2010, Diesel",
#   "location": "India, Maharashtra, Pune, Central Street Camp",
#   "price": "15,50,000",
#   "body_type": "LUXURY_SUV",
#   "brand": "Audi",
#   "model": "Q7",
#   "variant": "3.0 TDI quattro Premium",
#   "year": "2010.0",
#   "fuel": "Diesel",
#   "transmission": "Automatic",
#   "kms": "82000",
#   "owners": "2"
# }
# {
#   "title": "Skoda Superb Elegance 1.8 TSI Automatic, 2010, Petrol",
#   "location": "India, Maharashtra, Pune, Vishrant Wadi",
#   "price": "4,29,999",
#   "body_type": "LUXURY_SEDAN",
#   "brand": "Skoda",
#   "model": "Superb",
#   "variant": "2008-2013 Elegance 1.8 TSI AT",
#   "year": "2010.0",
#   "fuel": "Petrol",
#   "transmission": "Automatic",
#   "kms": "59000",
#   "owners": "2"
# }
# {
#   "title": "Hyundai Fluidic Verna 1.6 CRDi SX Automatic, 2012, Petrol",
#   "location": "India, Maharashtra, Pune, Vishrant Wadi",
#   "price": "4,99,999",
#   "body_type": "SEDAN",
#   "brand": "Hyundai",
#   "model": "Fluidic Verna",
#   "variant": "1.6 CRDi SX Automatic",
#   "year": "2012",
#   "fuel": "Petrol",
#   "transmission": "Manual",
#   "kms": "58000",
#   "owners": "1"
# }
# {
#   "title": "Skoda Rapid 1.5 TDI CR Ambition Plus, 2014, Diesel",
#   "location": "India, Maharashtra, Pune, Vishrant Wadi",
#   "price": "4,99,999",
#   "body_type": "SEDAN",
#   "brand": "Skoda",
#   "model": "Rapid",
#   "variant": "2013-2016 1.5 TDI Ambition Plus",
#   "year": "2014.0",
#   "fuel": "Diesel",
#   "transmission": "Manual",
#   "kms": "55000",
#   "owners": "1"
# }
# {
#   "title": "Honda Civic 1.8V Automatic, 2012, Petrol",
#   "location": "India, Maharashtra, Pune, Vishrant Wadi",
#   "price": "3,49,999",
#   "body_type": "SEDAN",
#   "brand": "Honda",
#   "model": "Civic",
#   "variant": "1.8 V AT",
#   "year": "2012.0",
#   "fuel": "Petrol",
#   "transmission": "Automatic",
#   "kms": "65000",
#   "owners": "2"
# }
# {
#   "title": "Volkswagen Vento Highline Petrol Automatic, 2011, Petrol",
#   "location": "India, Maharashtra, Pune, Vishrant Wadi",
#   "price": "3,49,999",
#   "body_type": "SEDAN",
#   "brand": "Volkswagen",
#   "model": "Vento",
#   "variant": "2010-2013 Petrol Highline AT",
#   "year": "2011",
#   "fuel": "Petrol",
#   "transmission": "Automatic",
#   "kms": "58000",
#   "owners": "2"
# }
# {
#   "title": "Honda Civic 2007 Petrol Well Maintained",
#   "location": "India, Maharashtra, Pune, Prabhat Road",
#   "price": "3,20,000",
#   "body_type": "SEDAN",
#   "brand": "Honda",
#   "model": "Civic",
#   "variant": "1.8 S MT",
#   "year": "2007",
#   "fuel": "Petrol",
#   "transmission": "Manual",
#   "kms": "92000",
#   "owners": "2"
# }
# {
#   "title": "Sell may alto",
#   "location": "India, Maharashtra, Pune, Shivaji Nagar",
#   "price": "75,000",
#   "body_type": "HATCHBACK",
#   "brand": "Maruti Suzuki",
#   "model": "Alto 800",
#   "variant": "Others",
#   "year": "2006",
#   "fuel": "Petrol",
#   "transmission": "Manual",
#   "kms": "690000",
#   "owners": "3"
# }
# {
#   "title": "Audi Q5 3.0 TDI quattro Technology Pack, 2012, Diesel",
#   "location": "India, Maharashtra, Pune, Swargate",
#   "price": "16,25,000",
#   "body_type": "LUXURY_SUV",
#   "brand": "Audi",
#   "model": "Q5",
#   "variant": "2012-2017 3.0 TDI Quattro Technology",
#   "year": "2012",
#   "fuel": "Diesel",
#   "transmission": "Automatic",
#   "kms": "62000",
#   "owners": "2"
# }
# {
#   "title": "Honda City 1.5 S Manual, 2009, Petrol",
#   "location": "India, Maharashtra, Pune, Vishrant Wadi",
#   "price": "3,15,000",
#   "body_type": "SEDAN",
#   "brand": "Honda",
#   "model": "City",
#   "variant": "2008-2011 1.5 S MT",
#   "year": "2009",
#   "fuel": "Petrol",
#   "transmission": "Manual",
#   "kms": "65000",
#   "owners": "1"
# }
# {
#   "title": "Maruti Suzuki Swift VXi 1.2 ABS BS-IV, 2009, Petrol",
#   "location": "India, Maharashtra, Pune, Vishrant Wadi",
#   "price": "2,65,000",
#   "body_type": "HATCHBACK",
#   "brand": "Maruti Suzuki",
#   "model": "Swift",
#   "variant": "VXi 1.2 ABS BS-IV",
#   "year": "2009",
#   "fuel": "Petrol",
#   "transmission": "Manual",
#   "kms": "87000",
#   "owners": "2"
# }
# {
#   "title": "Mahindra Quanto C6, 2013, Diesel",
#   "location": "India, Maharashtra, Pune, Vishrant Wadi",
#   "price": "3,55,000",
#   "body_type": "MUV",
#   "brand": "Mahindra",
#   "model": "Quanto",
#   "variant": "C6",
#   "year": "2013.0",
#   "fuel": "Diesel",
#   "transmission": "Manual",
#   "kms": "72000",
#   "owners": "1"
# }
# {
#   "title": "Hyundai Eon Magna +, 2013, Petrol",
#   "location": "India, Maharashtra, Pune, Vishrant Wadi",
#   "price": "2,55,000",
#   "body_type": "HATCHBACK",
#   "brand": "Hyundai",
#   "model": "EON",
#   "variant": "Magna +",
#   "year": "2013.0",
#   "fuel": "Petrol",
#   "transmission": "Manual",
#   "kms": "55000",
#   "owners": "1"
# }
# {
#   "title": "Nissan Sunny XL Diesel, 2015, Diesel",
#   "location": "India, Maharashtra, Pune, Vishrant Wadi",
#   "price": "3,99,000",
#   "body_type": "SEDAN",
#   "brand": "Nissan",
#   "model": "Sunny",
#   "variant": "Diesel XL",
#   "year": "2015.0",
#   "fuel": "Diesel",
#   "transmission": "Manual",
#   "kms": "64000",
#   "owners": "2"
# }
# {
#   "title": "Ford Free Style Titatinium TDCi, 2012, Diesel",
#   "location": "India, Maharashtra, Pune, Vishrant Wadi",
#   "price": "3,35,000",
#   "body_type": "HATCHBACK",
#   "brand": "Ford",
#   "model": "Freestyle",
#   "variant": "Titanium Diesel",
#   "year": "2012",
#   "fuel": "Diesel",
#   "transmission": "Manual",
#   "kms": "76000",
#   "owners": "1"
# }
# {
#   "title": "Renault Duster 110 PS RxZ Diesel, 2014, Diesel",
#   "location": "India, Maharashtra, Pune, Vishrant Wadi",
#   "price": "5,55,000",
#   "body_type": "SUV",
#   "brand": "Renault",
#   "model": "Duster",
#   "variant": "2012-2015 110PS Diesel RxZ",
#   "year": "2014",
#   "fuel": "Diesel",
#   "transmission": "Manual",
#   "kms": "52000",
#   "owners": "1"
# }
# {
#   "title": "Volkswagen Polo Comfortline Diesel, 2013, Diesel",
#   "location": "India, Maharashtra, Pune, Vishrant Wadi",
#   "price": "3,35,000",
#   "body_type": "HATCHBACK",
#   "brand": "Volkswagen",
#   "model": "Polo",
#   "variant": "2009-2013 Diesel Comfortline 1.2L",
#   "year": "2013",
#   "fuel": "Diesel",
#   "transmission": "Manual",
#   "kms": "95000",
#   "owners": "1"
# }
# {
#   "title": "Mercedes-Benz GLE COUPE 43 4MATIC, 2017, Petrol",
#   "location": "India, Maharashtra, Pune, Shivaji Nagar",
#   "price": "72,00,000",
#   "body_type": "OTHERS",
#   "brand": "Mercedes-Benz",
#   "model": "GLE COUPE",
#   "variant": "43 AMG Coupe",
#   "year": "2017",
#   "fuel": "Petrol",
#   "transmission": "Automatic",
#   "kms": "13652",
#   "owners": "1"
# }
# {
#   "title": "Maruti Suzuki Ritz Ldi BS-IV, 2016, Diesel",
#   "location": "India, Maharashtra, Pune, Nana Peth",
#   "price": "4,00,000",
#   "body_type": "HATCHBACK",
#   "brand": "Maruti Suzuki",
#   "model": "Ritz",
#   "variant": "Ldi BS-IV",
#   "year": "2016",
#   "fuel": "Diesel",
#   "transmission": "Manual",
#   "kms": "78000",
#   "owners": "1"
# }
# {
#   "title": "Mitsubishi Pajero SFX 2.8, 2009, Diesel",
#   "location": "India, Maharashtra, Pune, Vishrant Wadi",
#   "price": "4,99,000",
#   "body_type": "SUV",
#   "brand": "Mitsubishi",
#   "model": "Pajero",
#   "variant": "2002-2012 2.8 SFX",
#   "year": "2009.0",
#   "fuel": "Diesel",
#   "transmission": "Manual",
#   "kms": "117000",
#   "owners": "2"
# }
# {
#   "title": "Tata Zest XMS Diesel, 2015, Diesel",
#   "location": "India, Maharashtra, Pune, Vishrant Wadi",
#   "price": "3,85,000",
#   "body_type": "HATCHBACK",
#   "brand": "Tata",
#   "model": "Zest ",
#   "variant": "Quadrajet 1.3 XMS",
#   "year": "2015.0",
#   "fuel": "Diesel",
#   "transmission": "Manual",
#   "kms": "56000",
#   "owners": "1"
# }
# {
#   "title": "Ford Fiesta SXi 1.6, 2011, CNG & Hybrids",
#   "location": "India, Maharashtra, Pune, Vishrant Wadi",
#   "price": "2,45,000",
#   "body_type": "SEDAN",
#   "brand": "Ford",
#   "model": "Fiesta",
#   "variant": "SXi 1.6",
#   "year": "2011",
#   "fuel": "CNG & Hybrids",
#   "transmission": "Manual",
#   "kms": "75000",
#   "owners": "2"
# }
# {
#   "title": "Tata Manza GEX, 2010, Petrol",
#   "location": "India, Maharashtra, Pune, Vishrant Wadi",
#   "price": "1,44,000",
#   "body_type": "SEDAN",
#   "brand": "Tata",
#   "model": "Manza",
#   "variant": "GEX",
#   "year": "2010.0",
#   "fuel": "Petrol",
#   "transmission": "Manual",
#   "kms": "82000",
#   "owners": "2"
# }
# {
#   "title": "Ford Ecosport EcoSport Titanium Plus 1.5 TDCi, 2014, Diesel",
#   "location": "India, Maharashtra, Pune, Vishrant Wadi",
#   "price": "5,55,000",
#   "body_type": "SUV",
#   "brand": "Ford",
#   "model": "Ecosport",
#   "variant": "1.5 Diesel Titanium Plus",
#   "year": "2014.0",
#   "fuel": "Diesel",
#   "transmission": "Manual",
#   "kms": "74000",
#   "owners": "2"
# }
# {
#   "title": "Renault Duster 85 PS RXZ, 2016, Diesel",
#   "location": "India, Maharashtra, Pune, Vishrant Wadi",
#   "price": "6,75,000",
#   "body_type": "SUV",
#   "brand": "Renault",
#   "model": "Duster",
#   "variant": "85PS Diesel RxZ",
#   "year": "2016.0",
#   "fuel": "Diesel",
#   "transmission": "Manual",
#   "kms": "49000",
#   "owners": "1"
# }
# {
#   "title": "Honda Accord 3.0 V6 Automatic, 2006, Petrol",
#   "location": "India, Maharashtra, Pune, Vishrant Wadi",
#   "price": "1,44,000",
#   "body_type": "SEDAN",
#   "brand": "Honda",
#   "model": "Accord",
#   "variant": "3.0 V6 Automatic",
#   "year": "2006.0",
#   "fuel": "Petrol",
#   "transmission": "Automatic",
#   "kms": "99000",
#   "owners": "2"
# }
# {
#   "title": "Hyundai i10 2011 Petrol Well Maintained",
#   "location": "India, Maharashtra, Pune, Walvekar Nagar",
#   "price": "4,00,000",
#   "body_type": "HATCHBACK",
#   "brand": "Hyundai",
#   "model": "i10",
#   "variant": "2007-2010 Sportz 1.2",
#   "year": "2011",
#   "fuel": "Petrol",
#   "transmission": "Manual",
#   "kms": "60000",
#   "owners": "2"
# }
# {
#   "title": "Mercedes-Benz CL-Class 2008 Diesel Well Maintained",
#   "location": "India, Maharashtra, Pune, Ekbote Colony",
#   "price": "8,25,000",
#   "body_type": "LUXURY_SEDAN",
#   "brand": "Mercedes-Benz",
#   "model": "CL-Class",
#   "variant": "Others",
#   "year": "2008",
#   "fuel": "Diesel",
#   "transmission": "Automatic",
#   "kms": "75000",
#   "owners": "2"
# }
# {
#   "title": "Volkswagen Polo 2012 Diesel 81000 Km Driven",
#   "location": "India, Maharashtra, Pune, Gultekadi",
#   "price": "2,49,000",
#   "body_type": "HATCHBACK",
#   "brand": "Volkswagen",
#   "model": "Polo",
#   "variant": "1.2 MPI Comfortline",
#   "year": "2012",
#   "fuel": "Diesel",
#   "transmission": "Manual",
#   "kms": "81000",
#   "owners": "3"
# }
# {
#   "title": "2016 MERCEDES-BENZ E250D EDITION E PANAROMIC SUNROOF MH12",
#   "location": "India, Maharashtra, Pune, Apte Road",
#   "price": "25,50,000",
#   "body_type": "LUXURY_SEDAN",
#   "brand": "Mercedes-Benz",
#   "model": "E-Class",
#   "variant": "E250 Edition E",
#   "year": "2016",
#   "fuel": "Diesel",
#   "transmission": "Automatic",
#   "kms": "46700",
#   "owners": "2"
# }
# {
#   "title": "Maruti Suzuki Swift VDi, 2018, Diesel",
#   "location": "India, Maharashtra, Pune, Pune Cantonment",
#   "price": "7,40,000",
#   "body_type": "HATCHBACK",
#   "brand": "Maruti Suzuki",
#   "model": "Swift",
#   "variant": "2011-2014 VDI",
#   "year": "2018.0",
#   "fuel": "Diesel",
#   "transmission": "Manual",
#   "kms": "55000",
#   "owners": "1"
# }
# {
#   "title": "Toyota Innova 2.5 G 8 STR BS-IV, 2007, Diesel",
#   "location": "India, Maharashtra, Pune, Vishrant Wadi",
#   "price": "3,95,000",
#   "body_type": "SUV",
#   "brand": "Toyota",
#   "model": "Innova",
#   "variant": "2.5 G (Diesel) 8 Seater BS IV",
#   "year": "2007",
#   "fuel": "Diesel",
#   "transmission": "Manual",
#   "kms": "195000",
#   "owners": "2"
# }
# {
#   "title": "Mercedes-Benz CLA-Class 200 Petrol Sport, 2017, Petrol",
#   "location": "India, Maharashtra, Pune, Central Street Camp",
#   "price": "24,50,000",
#   "body_type": "LUXURY_SEDAN",
#   "brand": "Mercedes-Benz",
#   "model": "CLA",
#   "variant": "200 CGI Sport",
#   "year": "2017.0",
#   "fuel": "Petrol",
#   "transmission": "Automatic",
#   "kms": "21000",
#   "owners": "1"
# }
# {
#   "title": "Hyundai I10 Sportz 1.2, 2010, Petrol",
#   "location": "India, Maharashtra, Pune, Vishrant Wadi",
#   "price": "2,40,000",
#   "body_type": "HATCHBACK",
#   "brand": "Hyundai",
#   "model": "i10",
#   "variant": "2007-2010 Sportz 1.2",
#   "year": "2010",
#   "fuel": "Petrol",
#   "transmission": "Manual",
#   "kms": "84000",
#   "owners": "1"
# }
# {
#   "title": "Maruti Suzuki Ritz Vdi BS-IV, 2010, Diesel",
#   "location": "India, Maharashtra, Pune, Vishrant Wadi",
#   "price": "2,75,000",
#   "body_type": "HATCHBACK",
#   "brand": "Maruti Suzuki",
#   "model": "Ritz",
#   "variant": "Vdi BS-IV",
#   "year": "2010",
#   "fuel": "Diesel",
#   "transmission": "Manual",
#   "kms": "133000",
#   "owners": "1"
# }
# {
#   "title": "Land Rover Range Sport 3.0 TDV6 HSE Diesel, 2012, Diesel",
#   "location": "India, Maharashtra, Pune, Senapati Bapat Road",
#   "price": "33,00,000",
#   "body_type": "LUXURY_SUV",
#   "brand": "Land Rover",
#   "model": "Range Rover Sport",
#   "variant": "Sport 3.0 TDV6 HSE Diesel",
#   "year": "2012",
#   "fuel": "Diesel",
#   "transmission": "Automatic",
#   "kms": "62000",
#   "owners": "2"
# }
# {
#   "title": "Toyota Innova 2.5 E 8 STR, 2007, Diesel",
#   "location": "India, Maharashtra, Pune, Vishrant Wadi",
#   "price": "3,95,000",
#   "body_type": "SUV",
#   "brand": "Toyota",
#   "model": "Innova",
#   "variant": "2009-2011 2.5 E 8 STR",
#   "year": "2007",
#   "fuel": "Diesel",
#   "transmission": "Manual",
#   "kms": "195000",
#   "owners": "2"
# }
# {
#   "title": "Hyundai Verna Fluidic 1.4 VTVT CX, 2011, Petrol",
#   "location": "India, Maharashtra, Pune, Vishrant Wadi",
#   "price": "3,99,000",
#   "body_type": "SEDAN",
#   "brand": "Hyundai",
#   "model": "Verna",
#   "variant": "2011-2014 1.4 CX",
#   "year": "2011.0",
#   "fuel": "Petrol",
#   "transmission": "Manual",
#   "kms": "19000",
#   "owners": "1"
# }
# {
#   "title": "Honda City 1.5 S Manual, 2010, Petrol",
#   "location": "India, Maharashtra, Pune, Vishrant Wadi",
#   "price": "3,35,000",
#   "body_type": "SEDAN",
#   "brand": "Honda",
#   "model": "City",
#   "variant": "2008-2011 1.5 S MT",
#   "year": "2010",
#   "fuel": "Petrol",
#   "transmission": "Manual",
#   "kms": "69000",
#   "owners": "1"
# }
# {
#   "title": "Hyundai Santro Xing 2004",
#   "location": "India, Maharashtra, Pune, Shanti Nagar",
#   "price": "85,000",
#   "body_type": "HATCHBACK",
#   "brand": "Hyundai",
#   "model": "Santro Xing",
#   "variant": "XE",
#   "year": "2004",
#   "fuel": "Petrol",
#   "transmission": "Manual",
#   "kms": "90000",
#   "owners": "2"
# }
# {
#   "title": "Tata Indigo LS DiCOR BS-III, 2006, Petrol",
#   "location": "India, Maharashtra, Pune, Vishrant Wadi",
#   "price": "1,25,000",
#   "body_type": "SEDAN",
#   "brand": "Tata",
#   "model": "Indigo",
#   "variant": "LS Dicor",
#   "year": "2006",
#   "fuel": "Petrol",
#   "transmission": "Manual",
#   "kms": "65000",
#   "owners": "2"
# }
# {
#   "title": "Mahindra Bolero ZLX BS IV, 2015, Diesel",
#   "location": "India, Maharashtra, Pune, Pune Vidyapith",
#   "price": "6,50,000",
#   "body_type": "SUV",
#   "brand": "Mahindra",
#   "model": "Bolero",
#   "variant": "ZLX",
#   "year": "2015",
#   "fuel": "Diesel",
#   "transmission": "Manual",
#   "kms": "60000",
#   "owners": "1"
# }
# {
#   "title": "Mercedes-Benz R-Class R350 4MATIC, 2013, Petrol",
#   "location": "India, Maharashtra, Pune, Shivaji Nagar",
#   "price": "15,00,000",
#   "body_type": "LUXURY_SUV",
#   "brand": "Mercedes-Benz",
#   "model": "R-Class",
#   "variant": "R350 4MATIC",
#   "year": "2013",
#   "fuel": "Petrol",
#   "transmission": "Automatic",
#   "kms": "43000",
#   "owners": "2"
# }
# {
#   "title": "Fiat Punto Emotion Pack 1.4, 2013, Diesel",
#   "location": "India, Maharashtra, Pune, Vishrant Wadi",
#   "price": "2,99,000",
#   "body_type": "HATCHBACK",
#   "brand": "Fiat",
#   "model": "Punto",
#   "variant": "Punto Emotion Pack 1.4",
#   "year": "2013",
#   "fuel": "Diesel",
#   "transmission": "Manual",
#   "kms": "71000",
#   "owners": "1"
# }
# {
#   "title": "Honda City 1.5 V Automatic, 2010, Petrol",
#   "location": "India, Maharashtra, Pune, Vishrant Wadi",
#   "price": "3,65,000",
#   "body_type": "SEDAN",
#   "brand": "Honda",
#   "model": "City",
#   "variant": "2008-2011 1.5 V AT",
#   "year": "2010",
#   "fuel": "Petrol",
#   "transmission": "Automatic",
#   "kms": "67000",
#   "owners": "1"
# }
# {
#   "title": "Ford Fiesta SXi 1.4 TDCi, 2009, Diesel",
#   "location": "India, Maharashtra, Pune, Swargate",
#   "price": "2,50,000",
#   "body_type": "SEDAN",
#   "brand": "Ford",
#   "model": "Fiesta",
#   "variant": "2008-2011 1.4 SXi TDCi",
#   "year": "2009",
#   "fuel": "Diesel",
#   "transmission": "Manual",
#   "kms": "53000",
#   "owners": "1"
# }
# {
#   "title": "Maruti Suzuki Swift VDi BS-IV, 2012, Diesel",
#   "location": "India, Maharashtra, Pune, Walvekar Nagar",
#   "price": "4,65,000",
#   "body_type": "HATCHBACK",
#   "brand": "Maruti Suzuki",
#   "model": "Swift",
#   "variant": "VDI BS IV",
#   "year": "2012",
#   "fuel": "Diesel",
#   "transmission": "Manual",
#   "kms": "81000",
#   "owners": "1"
# }
# {
#   "title": "Audi A6 2.7 TDI, 2009, Diesel",
#   "location": "India, Maharashtra, Pune, Shivaji Nagar",
#   "price": "7,00,000",
#   "body_type": "LUXURY_SEDAN",
#   "brand": "Audi",
#   "model": "A6",
#   "variant": "2009-2011 2.7 TDI",
#   "year": "2009",
#   "fuel": "Diesel",
#   "transmission": "Automatic",
#   "kms": "90000",
#   "owners": "1"
# }
# {
#   "title": "Diesel 15 average tata safari single handed use",
#   "location": "India, Maharashtra, Pune, Senapati Bapat Road",
#   "price": "2,50,000",
#   "body_type": "SUV",
#   "brand": "Tata",
#   "model": "Safari",
#   "variant": "DICOR 2.2 EX 4x2 BS IV",
#   "year": "2008",
#   "fuel": "Diesel",
#   "transmission": "Manual",
#   "kms": "70000",
#   "owners": "1"
# }
# {
#   "title": "Skoda Rapid 2012 Petrol Well Maintained",
#   "location": "India, Maharashtra, Pune, Sarita Vihar",
#   "price": "2,75,000",
#   "body_type": "SEDAN",
#   "brand": "Skoda",
#   "model": "Rapid",
#   "variant": "1.6 MPI AT Ambition",
#   "year": "2012",
#   "fuel": "Petrol",
#   "transmission": "Manual",
#   "kms": "112100",
#   "owners": "1"
# }
# {
#   "title": "BMW X1 sDrive20d, 2015, Diesel",
#   "location": "India, Maharashtra, Pune, Central Street Camp",
#   "price": "13,00,000",
#   "body_type": "LUXURY_SUV",
#   "brand": "BMW",
#   "model": "X1",
#   "variant": "2010-2012 sDrive20d",
#   "year": "2015.0",
#   "fuel": "Diesel",
#   "transmission": "Automatic",
#   "kms": "45000",
#   "owners": "1"
# }
# {
#   "title": "Audi Q7 3.0 TDI quattro Premium, 2008, Diesel",
#   "location": "India, Maharashtra, Pune, Central Street Camp",
#   "price": "9,50,000",
#   "body_type": "LUXURY_SUV",
#   "brand": "Audi",
#   "model": "Q7",
#   "variant": "3.0 TDI quattro Premium",
#   "year": "2008.0",
#   "fuel": "Diesel",
#   "transmission": "Automatic",
#   "kms": "83000",
#   "owners": "2"
# }
# {
#   "title": "BMW X1 sDrive20d, 2017, Diesel",
#   "location": "India, Maharashtra, Pune, Shivaji Nagar",
#   "price": "20,50,000",
#   "body_type": "LUXURY_SUV",
#   "brand": "BMW",
#   "model": "X1",
#   "variant": "2010-2012 sDrive20d",
#   "year": "2017",
#   "fuel": "Diesel",
#   "transmission": "Automatic",
#   "kms": "56000",
#   "owners": "1"
# }
# {
#   "title": "Well maintained",
#   "location": "India, Maharashtra, Pune, Koregaon park",
#   "price": "18,50,000",
#   "body_type": "LUXURY_SEDAN",
#   "brand": "BMW",
#   "model": "5 Series",
#   "variant": "530d",
#   "year": "2010",
#   "fuel": "Diesel",
#   "transmission": "Automatic",
#   "kms": "149000",
#   "owners": "1"
# }
# {
#   "title": "Maruti Suzuki Swift 2017 Diesel single owner",
#   "location": "India, Maharashtra, Pune, Sadashiv Peth",
#   "price": "6,00,000",
#   "body_type": "HATCHBACK",
#   "brand": "Maruti Suzuki",
#   "model": "Swift",
#   "variant": "VDI Optional",
#   "year": "2017",
#   "fuel": "Diesel",
#   "transmission": "Manual",
#   "kms": "70876",
#   "owners": "1"
# }
# {
#   "title": "Mercedes-Benz GLA Class 2018 Diesel Well Maintained",
#   "location": "India, Maharashtra, Pune, Pune Cantonment",
#   "price": "18,60,000",
#   "body_type": "LUXURY_SUV",
#   "brand": "Mercedes-Benz",
#   "model": "GLA Class",
#   "variant": "2014-2017 200 D Sport Edition",
#   "year": "2018",
#   "fuel": "Diesel",
#   "transmission": "Automatic",
#   "kms": "55000",
#   "owners": "1"
# }
# {
#   "title": "Honda City 1.5 V Manual, 2010, Petrol",
#   "location": "India, Maharashtra, Pune, Vishrant Wadi",
#   "price": "3,55,000",
#   "body_type": "SEDAN",
#   "brand": "Honda",
#   "model": "City",
#   "variant": "2008-2011 1.5 V MT",
#   "year": "2010",
#   "fuel": "Petrol",
#   "transmission": "Manual",
#   "kms": "67000",
#   "owners": "1"
# }
# {
#   "title": "Maruti Suzuki Celerio ZXi, 2014, Petrol",
#   "location": "India, Maharashtra, Pune, Vishrant Wadi",
#   "price": "3,85,000",
#   "body_type": "HATCHBACK",
#   "brand": "Maruti Suzuki",
#   "model": "Celerio",
#   "variant": "ZXI MT",
#   "year": "2014",
#   "fuel": "Petrol",
#   "transmission": "Manual",
#   "kms": "45000",
#   "owners": "1"
# }
# {
#   "title": "Hyundai Verna Fluidic 1.6 VTVT SX, 2014, Petrol",
#   "location": "India, Maharashtra, Pune, Vishrant Wadi",
#   "price": "5,35,000",
#   "body_type": "SEDAN",
#   "brand": "Hyundai",
#   "model": "Verna",
#   "variant": "Fluidic 1.6 VTVT SX",
#   "year": "2014",
#   "fuel": "Petrol",
#   "transmission": "Manual",
#   "kms": "65000",
#   "owners": "1"
# }
# {
#   "title": "Innova 2005",
#   "location": "India, Maharashtra, Pune, Parvati",
#   "price": "3,50,000",
#   "body_type": "SUV",
#   "brand": "Toyota",
#   "model": "Innova",
#   "variant": "2.5 EV (Diesel) PS 7 Seater BS IV",
#   "year": "2005",
#   "fuel": "Diesel",
#   "transmission": "Manual",
#   "kms": "201000",
#   "owners": "2"
# }
# {
#   "title": "Mahindra Xylo 2014 Diesel Good Condition",
#   "location": "India, Maharashtra, Pune, Sarita Vihar",
#   "price": "6,10,000",
#   "body_type": "SUV",
#   "brand": "Mahindra",
#   "model": "Xylo",
#   "variant": "D4",
#   "year": "2014",
#   "fuel": "Diesel",
#   "transmission": "Manual",
#   "kms": "41990",
#   "owners": "1"
# }
# {
#   "title": "Hyundai i20 2009 CNG & Hybrids Well Maintained",
#   "location": "India, Maharashtra, Pune, Prem Nagar",
#   "price": "2,70,000",
#   "body_type": "HATCHBACK",
#   "brand": "Hyundai",
#   "model": "i20",
#   "variant": "2009-2011 Magna",
#   "year": "2009",
#   "fuel": "CNG & Hybrids",
#   "transmission": "Manual",
#   "kms": "114000",
#   "owners": "3"
# }
# {
#   "title": "Tata Nano 2011 Petrol 67000 Km Driven",
#   "location": "India, Maharashtra, Pune, Vishrant Wadi",
#   "price": "55,000",
#   "body_type": "HATCHBACK",
#   "brand": "Tata",
#   "model": "Nano",
#   "variant": "2009-2011 Lx",
#   "year": "2011",
#   "fuel": "Petrol",
#   "transmission": "Manual",
#   "kms": "67000",
#   "owners": "3"
# }
# {
#   "title": "Maruti Suzuki Swift 2010 Diesel 79000 Km Driven",
#   "location": "India, Maharashtra, Pune, Sarasbaug",
#   "price": "3,62,999",
#   "body_type": "HATCHBACK",
#   "brand": "Maruti Suzuki",
#   "model": "Swift",
#   "variant": "2011-2014 VDI",
#   "year": "2010",
#   "fuel": "Diesel",
#   "transmission": "Manual",
#   "kms": "79000",
#   "owners": "1"
# }
# {
#   "title": "BMW 3 Series 320d M Sport, 2017, Diesel",
#   "location": "India, Maharashtra, Pune, Shivaji Nagar",
#   "price": "31,00,000",
#   "body_type": "LUXURY_SEDAN",
#   "brand": "BMW",
#   "model": "3 Series",
#   "variant": "320d M Sport",
#   "year": "2017",
#   "fuel": "Diesel",
#   "transmission": "Automatic",
#   "kms": "27000",
#   "owners": "1"
# }
# {
#   "title": "Maruti Suzuki Swift Dzire VXI Automatic, 2017, Petrol",
#   "location": "India, Maharashtra, Pune, Walvekar Nagar",
#   "price": "6,50,000",
#   "body_type": "SEDAN",
#   "brand": "Maruti Suzuki",
#   "model": "Swift Dzire",
#   "variant": "AMT VXI",
#   "year": "2017",
#   "fuel": "Petrol",
#   "transmission": "Automatic",
#   "kms": "64000",
#   "owners": "1"
# }
# {
#   "title": "\u0911\u091f\u094b \u0930\u093f\u0915\u094d\u0936\u093e",
#   "location": "India, Maharashtra, Pune, Bopodi",
#   "price": "80,000",
#   "body_type": "OTHERS",
#   "brand": "Bajaj",
#   "model": "RE60",
#   "variant": "Others",
#   "year": "2004",
#   "fuel": "CNG & Hybrids",
#   "transmission": "Manual",
#   "kms": "898312",
#   "owners": "1"
# }
# {
#   "title": "Chevrolet Enjoy 1.4 LS 8 STR, 2014, CNG & Hybrids",
#   "location": "India, Maharashtra, Pune, Vishrant Wadi",
#   "price": "3,65,000",
#   "body_type": "HATCHBACK",
#   "brand": "Chevrolet",
#   "model": "Enjoy",
#   "variant": "1.4 LS 8",
#   "year": "2014",
#   "fuel": "CNG & Hybrids",
#   "transmission": "Manual",
#   "kms": "65000",
#   "owners": "1"
# }
# {
#   "title": "Hyundai Verna Fluidic 1.6 VTVT EX, 2011, Petrol",
#   "location": "India, Maharashtra, Pune, Vishrant Wadi",
#   "price": "3,99,000",
#   "body_type": "SEDAN",
#   "brand": "Hyundai",
#   "model": "Verna",
#   "variant": "2011-2014 1.6 EX VTVT",
#   "year": "2011.0",
#   "fuel": "Petrol",
#   "transmission": "Manual",
#   "kms": "56000",
#   "owners": "1"
# }
# {
#   "title": "Hyundai Verna Fluidic 1.6 VTVT SX, 2012, Petrol",
#   "location": "India, Maharashtra, Pune, Vishrant Wadi",
#   "price": "3,99,000",
#   "body_type": "SEDAN",
#   "brand": "Hyundai",
#   "model": "Verna",
#   "variant": "Fluidic 1.6 VTVT SX",
#   "year": "2012.0",
#   "fuel": "Petrol",
#   "transmission": "Manual",
#   "kms": "22000",
#   "owners": "1"
# }
# {
#   "title": "Mercedes-Benz S-Class 350, 2016, Diesel",
#   "location": "India, Maharashtra, Pune, Shivaji Nagar",
#   "price": "50,00,000",
#   "body_type": "LUXURY_SEDAN",
#   "brand": "Mercedes-Benz",
#   "model": "S-Class",
#   "variant": "S 350 d",
#   "year": "2016",
#   "fuel": "Diesel",
#   "transmission": "Automatic",
#   "kms": "32000",
#   "owners": "2"
# }
# {
#   "title": "BMW X1 sDrive20d, 2017, Diesel",
#   "location": "India, Maharashtra, Pune, Shivaji Nagar",
#   "price": "20,50,000",
#   "body_type": "LUXURY_SUV",
#   "brand": "BMW",
#   "model": "X1",
#   "variant": "2010-2012 sDrive20d",
#   "year": "2017",
#   "fuel": "Diesel",
#   "transmission": "Automatic",
#   "kms": "56000",
#   "owners": "1"
# }
# {
#   "title": "Volkswagen Polo Comfortline Diesel, 2011, Diesel",
#   "location": "India, Maharashtra, Pune, Vishrant Wadi",
#   "price": "2,75,000",
#   "body_type": "HATCHBACK",
#   "brand": "Volkswagen",
#   "model": "Polo",
#   "variant": "2009-2013 Diesel Comfortline 1.2L",
#   "year": "2011",
#   "fuel": "Diesel",
#   "transmission": "Manual",
#   "kms": "129000",
#   "owners": "2"
# }
# {
#   "title": "Maruti Suzuki Ertiga VDi, 2013, Diesel",
#   "location": "India, Maharashtra, Pune, Rasta Peth",
#   "price": "6,25,000",
#   "body_type": "MUV",
#   "brand": "Maruti Suzuki",
#   "model": "Ertiga",
#   "variant": "2012-2015 VDI",
#   "year": "2013",
#   "fuel": "Diesel",
#   "transmission": "Manual",
#   "kms": "42406",
#   "owners": "1"
# }
# {
#   "title": "Hyundai I10 Sportz 1.2, 2010, Petrol",
#   "location": "India, Maharashtra, Pune, Rasta Peth",
#   "price": "2,20,000",
#   "body_type": "HATCHBACK",
#   "brand": "Hyundai",
#   "model": "i10",
#   "variant": "2007-2010 Sportz 1.2",
#   "year": "2010",
#   "fuel": "Petrol",
#   "transmission": "Manual",
#   "kms": "74185",
#   "owners": "1"
# }
# {
#   "title": "Maruti suzuki swift vxi 2007 model second owner excellent condition.",
#   "location": "India, Maharashtra, Pune, Central Street Camp",
#   "price": "1,69,999",
#   "body_type": "HATCHBACK",
#   "brand": "Maruti Suzuki",
#   "model": "Swift",
#   "variant": "VXI",
#   "year": "2007",
#   "fuel": "Petrol",
#   "transmission": "Manual",
#   "kms": "89999",
#   "owners": "2"
# }
# {
#   "title": "Maruti Suzuki Swift VDi, 2007, Diesel",
#   "location": "India, Maharashtra, Pune, Swargate",
#   "price": "2,75,000",
#   "body_type": "HATCHBACK",
#   "brand": "Maruti Suzuki",
#   "model": "Swift",
#   "variant": "2011-2014 VDI",
#   "year": "2007",
#   "fuel": "Diesel",
#   "transmission": "Manual",
#   "kms": "145000",
#   "owners": "3"
# }
# {
#   "title": "Honda Brio S Manual, 2014, Petrol",
#   "location": "India, Maharashtra, Pune, Shivaji Nagar",
#   "price": "4,00,000",
#   "body_type": "HATCHBACK",
#   "brand": "Honda",
#   "model": "Brio",
#   "variant": "2011-2013 S MT",
#   "year": "2014",
#   "fuel": "Petrol",
#   "transmission": "Manual",
#   "kms": "17198",
#   "owners": "1"
# }
# {
#   "title": "Hyundai Xcent",
#   "location": "India, Maharashtra, Pune, Guruwar Peth",
#   "price": "2,30,000",
#   "body_type": "SEDAN",
#   "brand": "Hyundai",
#   "model": "Xcent",
#   "variant": "Others",
#   "year": "2017",
#   "fuel": "Diesel",
#   "transmission": "Manual",
#   "kms": "100000",
#   "owners": "1"
# }
# {
#   "title": "Volkswagen Vento Highline Petrol Automatic, 2013, Petrol",
#   "location": "India, Maharashtra, Pune, Nana Peth",
#   "price": "4,40,000",
#   "body_type": "SEDAN",
#   "brand": "Volkswagen",
#   "model": "Vento",
#   "variant": "2010-2013 Petrol Highline AT",
#   "year": "2013",
#   "fuel": "Petrol",
#   "transmission": "Automatic",
#   "kms": "69000",
#   "owners": "1"
# }
# {
#   "title": "Fiat Avventura Emotion Multijet 1.3, 2014, Diesel",
#   "location": "India, Maharashtra, Pune, Shivaji Nagar",
#   "price": "4,55,000",
#   "body_type": "SUV",
#   "brand": "Fiat",
#   "model": "Avventura",
#   "variant": "MULTIJET Emotion",
#   "year": "2014",
#   "fuel": "Diesel",
#   "transmission": "Manual",
#   "kms": "51000",
#   "owners": "1"
# }
# {
#   "title": "Honda Civic 1.8V Automatic, 2012, Petrol",
#   "location": "India, Maharashtra, Pune, Vishrant Wadi",
#   "price": "3,50,000",
#   "body_type": "SEDAN",
#   "brand": "Honda",
#   "model": "Civic",
#   "variant": "1.8 V AT",
#   "year": "2012",
#   "fuel": "Petrol",
#   "transmission": "Automatic",
#   "kms": "65000",
#   "owners": "2"
# }
# {
#   "title": "Maruti Suzuki Swift Dzire ZDI Plus AMT (Automatic), 2017, Diesel",
#   "location": "India, Maharashtra, Pune, Rasta Peth",
#   "price": "8,25,000",
#   "body_type": "SEDAN",
#   "brand": "Maruti Suzuki",
#   "model": "Swift Dzire",
#   "variant": "AMT ZDI Plus",
#   "year": "2017",
#   "fuel": "Diesel",
#   "transmission": "Automatic",
#   "kms": "38039",
#   "owners": "1"
# }
# {
#   "title": "Mercedes-Benz S-Class 350, 2016, Diesel",
#   "location": "India, Maharashtra, Pune, Shivaji Nagar",
#   "price": "50,00,000",
#   "body_type": "LUXURY_SEDAN",
#   "brand": "Mercedes-Benz",
#   "model": "S-Class",
#   "variant": "S 350 d",
#   "year": "2016",
#   "fuel": "Diesel",
#   "transmission": "Automatic",
#   "kms": "32000",
#   "owners": "2"
# }
# {
#   "title": "Maruti Suzuki Alto K10 VXi Automatic, 2019, Petrol",
#   "location": "India, Maharashtra, Pune, Rasta Peth",
#   "price": "4,25,000",
#   "body_type": "HATCHBACK",
#   "brand": "Maruti Suzuki",
#   "model": "Alto K10",
#   "variant": "VXI AMT",
#   "year": "2019",
#   "fuel": "Petrol",
#   "transmission": "Automatic",
#   "kms": "7602",
#   "owners": "1"
# }
# 2020-12-27 19:40:18 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.olx.in/api/relevance/v2/search?category=84&facet_limit=100&lang=en&location=4059014&location_facet_limit=20&platform=web-desktop&size=40&user=16fecf81399x6039b937&page=1> (referer: None)
# 2020-12-27 19:40:18 [scrapy.core.scraper] ERROR: Spider error processing <GET https://www.olx.in/api/relevance/v2/search?category=84&facet_limit=100&lang=en&location=4059014&location_facet_limit=20&platform=web-desktop&size=40&user=16fecf81399x6039b937&page=1> (referer: None)
# Traceback (most recent call last):
#   File "C:\Users\ehtesham\Anaconda3\lib\site-packages\twisted\internet\defer.py", line 654, in _runCallbacks
#     current.result = callback(current.result, *args, **kw)
#   File "<ipython-input-3-f7d0bf8fb4b9>", line 30, in parse
#     'body_type': offer['car_body_type'],
# KeyError: 'car_body_type'
# 2020-12-27 19:40:18 [scrapy.core.engine] INFO: Closing spider (finished)
# 2020-12-27 19:40:18 [scrapy.statscollectors] INFO: Dumping Scrapy stats:
# {'downloader/request_bytes': 2260,
#  'downloader/request_count': 5,
#  'downloader/request_method_count/GET': 5,
#  'downloader/response_bytes': 223327,
#  'downloader/response_count': 5,
#  'downloader/response_status_count/200': 5,
#  'elapsed_time_seconds': 1.036128,
#  'finish_reason': 'finished',
#  'finish_time': datetime.datetime(2020, 12, 27, 14, 10, 18, 390836),
#  'log_count/DEBUG': 5,
#  'log_count/ERROR': 5,
#  'log_count/INFO': 10,
#  'response_received_count': 5,
#  'scheduler/dequeued': 5,
#  'scheduler/dequeued/memory': 5,
#  'scheduler/enqueued': 5,
#  'scheduler/enqueued/memory': 5,
#  'spider_exceptions/IndexError': 2,
#  'spider_exceptions/KeyError': 2,
#  'spider_exceptions/UnicodeEncodeError': 1,
#  'start_time': datetime.datetime(2020, 12, 27, 14, 10, 17, 354708)}
# 2020-12-27 19:40:18 [scrapy.core.engine] INFO: Spider closed (finished)
# {
#   "title": "Hyundai i20 Active 1.2 SX, 2017, Petrol",
#   "location": "India, Maharashtra, Pune, Rasta Peth",
#   "price": "7,30,000",
#   "body_type": "HATCHBACK",
#   "brand": "Hyundai",
#   "model": "i20 Active",
#   "variant": "1.2 SX",
#   "year": "2017",
#   "fuel": "Petrol",
#   "transmission": "Manual",
#   "kms": "10244",
#   "owners": "1"
# }
# {
#   "title": "Maruti Suzuki Baleno Delta Diesel, 2017, Diesel",
#   "location": "India, Maharashtra, Pune, Shivaji Nagar",
#   "price": "7,25,000",
#   "body_type": "HATCHBACK",
#   "brand": "Maruti Suzuki",
#   "model": "Baleno",
#   "variant": "1.3 Delta",
#   "year": "2017",
#   "fuel": "Diesel",
#   "transmission": "Manual",
#   "kms": "66449",
#   "owners": "1"
# }
# {
#   "title": "Audi Q3 2.0 TDI quattro Premium, 2012, Diesel",
#   "location": "India, Maharashtra, Pune, Shivaji Nagar",
#   "price": "14,95,000",
#   "body_type": "LUXURY_SUV",
#   "brand": "Audi",
#   "model": "Q3",
#   "variant": "2.0 TDI quattro Premium",
#   "year": "2012",
#   "fuel": "Diesel",
#   "transmission": "Automatic",
#   "kms": "78000",
#   "owners": "1"
# }
